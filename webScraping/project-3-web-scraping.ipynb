# %% [markdown]
# # Project 3:  Web Scraping
# ### Finding Underpriced RVs on Craigslist
#
# ![](https://snag.gy/WrdUMx.jpg)

# %% [markdown]
# In this project we will be practicing our web scraping skills.  You can use Scrapy or Python requests in order to complete this project.  It may be helpful to write some prototype code in this notebook to test your assumptions, then move it into a Python file that can be run from the command line.
#
# > In order to run code from the command line, instead of the notebook, you just need to save your code to a file (with a .py extension), and run it using the Python interpreter:<br><br>
# > `python my_file.py`
#
# You will be building a process to scrape a single category of search results on Craigslist, that can easily be applied to other categories by changing the search terms.  The main goal is to be able to target and scrape a single page given a set of parameters.
#
# **If you use Scrapy, provide your code in a folder.**

# %% [markdown]
# ## Import your libraries for scrapy / requests / pandas / numpy / etc
# Setup whichever libraries you need. Review past material for reference.

# %%
# PREPARE REQUIRED LIBRARIES
import numpy as np
import requests
import pandas as pd
import scrapy

# %% [markdown]
# ## 1.  Scrape for the largest US cities (non-exhaustive list)
# Search, research, and scrape Wikipedia for a list of the largest US cities.  There are a few sources but find one that is in a nice table.  We don't want all cities, just signifficant cities.  Examine your source.  Look for what can be differentiable.
#
# - Use requests
# - Build XPath query(ies)
# - Extract to a list
# - Clean your list

# %%
# SCRAPE WIKIPEDI<img src="http://imgur.com/xDpSobf.png" style="float: left; margin: A FOR LARGEST US CITIES (NON-EXHAUSTIVE LIST)

from scrapy.selector import Selector
from scrapy.http import HtmlResponse

import requests

response = requests.get('https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population')
HTML = response.text  
HTML[0:150]
# Out:
# u'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of United States cities by population - Wiki'

# %% [markdown]
# ## 1.2 Only retain cities with properly formed ASCII
#
# Optionally, filter out any cities with impropper ASCII characters.  A smaller list will be easier to look at.  However you may not need to filter these if you spend more time scraping a more concise city list.  This list should help you narrow down the list of regional Craigslist sites.

# %%
# ONLY RETAIN PROPERLY FORMED CITIES WITH FILTERING FUNCTION

city = Selector(text=HTML).xpath('//td/i/a/text()|//td[2]/a/text()').extract()

# %% [markdown]
# ## 2.  Write a function to capture current pricing information via Craigslist in one city.
# Choose a city from your scraped data, then go to the cooresponding city section on Craigslist, searching for "rv" in the auto section.  Write a method that pulls out the prices.

# %%
response = requests.get('https://sfbay.craigslist.org/search/rva?min_price=100')
HTML = response.text  
HTML[0:150]
# Out:
# u'\ufeff<!DOCTYPE html>\n\n<html class="no-js"><head>\n    <title>SF bay area recreational vehicles  - craigslist</title>\n\n    <meta name="description" content='

# %% [markdown]
# ## 2.1 Create a mapping of cities to cooresponding regional Craigslist URLs
#
# Major US cities on Craigslist typically have their own cooresponding section (ie: SFBay Area, NYC, Boston, Miami, Seattle, etc).  Later, you will use these to query search results for various metropolitian regions listed on Craigslist.  Between the major metropolitan Craigslist sites, the only thing that will differ is the URL's that correspond to them.
#
# The point of the "mapping":  Create a data structure that allows you to iterate with both the name of the city from Wikipedia, with the cooresponding variable that that will allow you to construct each craigslist URL for each region.
#
# > For San Francsico (the Bay Area metropolitan area), the url for the RV search result is:
# > http://sfbay.craigslist.org/search/sss?query=rv
# >
# > The convention is http://[region].craigslist.org/search/sss?query=rf
# > Replacing [region] with the cooresponding city name will allow you to quickly iterate through each regional Craigslist site, and scrape the prices from the search results.  Keep this in mind while you build this "mapping".

# %%
Selector(text=HTML).xpath('//link[@rel="next"]/@href').extract()
# Out:
# [u'https://sfbay.craigslist.org/search/rva?s=120&min_price=100']

# %%
Selector(text=HTML).xpath('//p/a[@class="result-title hdrlnk"]/text()').extract()
# Out:
# [u'Daily rental Mercedes based',
#  u'RV for sale',
#  u"30' 1998 Mallard. Bunkhouse Model",
#  u'1987 "Sunrader" Toyota MH',
#  u'camping trailer for sale',
#  u'2004 Lance 820 Cab over Camper',
#  u'RV Covers, Trailer Covers,',
#  u'35 ft cyclone',
#  u'1978 Chevy RV',
#  u"1979 26'Winnebago",
#  u'Gorgeous Monaco Diplomat 2006',
#  u'Onan 4.0 Generator',
#  u'L+I+FE STYLE-\U0001f4a5\U0001f4a5\U0001f4a5 19..90 Winnebago Minnie',
#  u"2004- 27' Minnie Winnebago WF427P",
#  u'\u273fBeautiful Like-New RV for Rent - with Slide Out - Sleeps 6!',
#  u'RV for Rent - Beautiful RVs at Affordable Prices!!!',
#  u"\u27b830' RV For Rent - Like New! with 4 Bunk beds - RARE! Sleeps up to 10!",
#  u"2001 34' Monaco with slide",
#  u'2002 Ultra Gulf Stream, Class A- Low miles',
#  u'2007 Forest River Georgetown SE 350DS Bunkhouse',
#  u'Airstream Bathtubs',
#  u"Tear Drop Trailer 14'",
#  u"1997 Holiday Rambler Vacationer 38' with slide out",
#  u'1987 Toyota Sunrader RV',
#  u'pop up tent trailer',
#  u"2011 SABRE 31' Travel Trailer LIKE NEW!!!!$$$$####",
#  u"1997 Southwind Storm 31'",
#  u'Price reduced! Incredible deal on truck and camper combo',
#  u'1984 Holiday Rambler -- AlumaLife XL 27 ft',
#  u"2003 R-Vision Condor 30' Workhorse",
#  u'Cab over camper',
#  u"1998 CLASS A 35' SOUTHWIND BY FLEETWOOD MOTORHOME! 1/2 OFF SALE!! FUN!",
#  u"2017 24' Keystone Springdale travel trailer for rent-Delivered or P/U",
#  u"Airstream Safari 25'ft",
#  u'RV Tioga Montara great condition',
#  u'Wilderness Northwest (99) with Complete Kitchen Area and More Closet',
#  u'1986 Vacationeer 30ft mobil home trailer',
#  u'2015 Coachman Clipper 17ft Travel Trailer',
#  u'2015 Thor Axis w slide 24.1',
#  u'2015 Thor Axis w slide 24.1',
#  u'40 ft. Diesel Pusher Holiday Rambler Imperial',
#  u'2002 Coleman Sun Valley(by Fleetwood) with AIR CONDITIONER',
#  u"Space for a Household to Vacation In Comfort - Fleetwood Revolution ('",
#  u'Cab Over Camper 2106',
#  u'2002 28ft Komfort Fifth Wheel',
#  u"2001 Fleetwood Prowler Park Model 39' Trailer",
#  u'Fleetwood Tioga Arrow',
#  u"28' Travel Trailer",
#  u'1997 Lance Truck Camper 10\' 8" Lance Legend 880',
#  u'2005 Keystone Springdale 24ft 5th Wheel Camper',
#  u"Classic Travel Trailer 19'",
#  u'Keystone Cambridge 361RLS 39ft 5th wheel',
#  u'Keystone Cambridge 361RLS 39ft 5th wheel',
#  u'Keystone Cambridge 361RLS 39ft 5th wheel',
#  u"2004 Sunseeker by Forest River 31' Class C 50K Miles",
#  u'Airplane - Ercoupe - Not a cessna',
#  u'1974 Airstream Overlander',
#  u'2016 forest river Salem',
#  u'Sunnybrook Fifthwheel 5th 27 RKFS-Like new',
#  u'1999 wilderness by fleetwood',
#  u'Komfort Trailer',
#  u"13' Scamp trailer excellent condition!!",
#  u'GOING TO BURNING MAN',
#  u'2007 Keystone Springdale 189 Clearwater Edition RV',
#  u'Gas Golf Cart +Private Resort Deed',
#  u'1997 Skyline Nomad 19ft',
#  u"1998 28' Four Winds Motor home",
#  u'TAB camper trailer',
#  u'Monaco Class A with super slide',
#  u'Canned Ham / Travel Trailer parts',
#  u'CAMPER 2004 EAGLE CAP M850',
#  u"2006 30' Keystone Outback travel trailer 14' slide",
#  u'Palomino pop up cabover camper',
#  u'1998 Fleetwood Bounder 32 Foot',
#  u'2012 Sunnybrook Raven fifth wheel',
#  u'26.5 ft. Lazy Daze RV, Rear bath, blue / white exterior',
#  u'1995 FourWheel popup camper',
#  u'2004 Safari Trek 30PBS - Rare find! This Trek has views!',
#  u"32' Class A Winnebago Brave",
#  u"23' 2007 RV Chateau Sport - 28k miles - Mint Condition!!",
#  u"2007 Chateau Sport RV 23' - 28k miles in almost new condition",
#  u'2017 Class C Winnebago Minnie Winnie 25B - must sell',
#  u"Toys Houler 2007 38'",
#  u'Park model Clearview trailer',
#  u'2006 Okanagan 10UD - Fully Loaded Truck Camper!',
#  u'Toyota Dolphin',
#  u'1984 Chevy Austin 21ft Class C 45,000 original miles',
#  u'RV',
#  u'1995 VW Eurovan Camper',
#  u"1986 Bluebird Wonderlodge-40' Motor Home Class A",
#  u'2016 Keystone Ultra Lite Bullet RV/ Trailer like new Must Sell!!!',
#  u"1992 24' Terry Trailer",
#  u"Remodeled 25' Mallard Sprinter RV",
#  u'2017 wildcat maxx 28rkx',
#  u'12 Ft Boles Aero EXTREMELY RARE',
#  u'Avant-Garde Park Model',
#  u'2003 Southwind 32V',
#  u'2007 cougar 29ft 5th wheel',
#  u'Cougar',
#  u'2012 Rockwood Mini-Lite',
#  u'2016 Thor Motor Coach Chateau 29G',
#  u'RV for sale',
#  u'4th JULY PISMO BEACH OCENANO DUNES  reservation',
#  u'Class A Diesel Pusher Motorhome',
#  u"1971 Lazy Daze 18' RV Burning Man Special",
#  u'Itasca Spirit - Low Miles, Warranty, Major Upgrades',
#  u'2004 Winnebago Sightseer class A 29FT',
#  u'1996 RV Majestic Flyer',
#  u'Ford Searcher 28F 14k Miles RV Smogged 2017 Runing Great',
#  u'2000 COACHMEN MIRADA CLASS A MOTORHOME',
#  u'2016 Winnebago Minnie Winnie 22R - Super Clean and Ready for Summer!',
#  u'2017 Forest River RV Salem Hemisphere 282RK Travel Trailer',
#  u'2007 Lance 815 - For Standard 6ft or 8 ft bed - Very Clean!',
#  u'1998 BANTAM TRAIL-LITE (B-17 HYBRID',
#  u'1963 Airstream Safari',
#  u'Toy hauler jayco Talon zx',
#  u'Toy Hauler, Camper, Dirt Bike/Motorcycle Trailer/ MOVER',
#  u'TOY HAULER K2 trailer',
#  u'1991 TOYOTA ODYSSEY V6 *66,093 ORIGINAL MILES*',
#  u"1979 Airstream Excella 24' motorhome"]

# %%
Selector(text=HTML).xpath('//span[@class="result-meta"]/span[@class="result-price"]').extract()
# Out:
# [u'<span class="result-price">$180</span>',
#  u'<span class="result-price">$6300</span>',
#  u'<span class="result-price">$6450</span>',
#  u'<span class="result-price">$10900</span>',
#  u'<span class="result-price">$8900</span>',
#  u'<span class="result-price">$12500</span>',
#  u'<span class="result-price">$795</span>',
#  u'<span class="result-price">$26900</span>',
#  u'<span class="result-price">$400</span>',
#  u'<span class="result-price">$3200</span>',
#  u'<span class="result-price">$106000</span>',
#  u'<span class="result-price">$150</span>',
#  u'<span class="result-price">$2016</span>',
#  u'<span class="result-price">$40000</span>',
#  u'<span class="result-price">$165</span>',
#  u'<span class="result-price">$165</span>',
#  u'<span class="result-price">$175</span>',
#  u'<span class="result-price">$25000</span>',
#  u'<span class="result-price">$6900</span>',
#  u'<span class="result-price">$40900</span>',
#  u'<span class="result-price">$150</span>',
#  u'<span class="result-price">$17500</span>',
#  u'<span class="result-price">$17000</span>',
#  u'<span class="result-price">$11900</span>',
#  u'<span class="result-price">$500</span>',
#  u'<span class="result-price">$20000</span>',
#  u'<span class="result-price">$10900</span>',
#  u'<span class="result-price">$44999</span>',
#  u'<span class="result-price">$6500</span>',
#  u'<span class="result-price">$5000</span>',
#  u'<span class="result-price">$6800</span>',
#  u'<span class="result-price">$14888</span>',
#  u'<span class="result-price">$135</span>',
#  u'<span class="result-price">$2000</span>',
#  u'<span class="result-price">$3000</span>',
#  u'<span class="result-price">$28650</span>',
#  u'<span class="result-price">$1200</span>',
#  u'<span class="result-price">$13800</span>',
#  u'<span class="result-price">$62000</span>',
#  u'<span class="result-price">$62000</span>',
#  u'<span class="result-price">$20000</span>',
#  u'<span class="result-price">$4100</span>',
#  u'<span class="result-price">$26050</span>',
#  u'<span class="result-price">$2106</span>',
#  u'<span class="result-price">$13700</span>',
#  u'<span class="result-price">$14900</span>',
#  u'<span class="result-price">$18000</span>',
#  u'<span class="result-price">$14500</span>',
#  u'<span class="result-price">$9500</span>',
#  u'<span class="result-price">$11500</span>',
#  u'<span class="result-price">$5500</span>',
#  u'<span class="result-price">$26000</span>',
#  u'<span class="result-price">$26000</span>',
#  u'<span class="result-price">$26000</span>',
#  u'<span class="result-price">$25999</span>',
#  u'<span class="result-price">$12000</span>',
#  u'<span class="result-price">$24900</span>',
#  u'<span class="result-price">$22000</span>',
#  u'<span class="result-price">$10900</span>',
#  u'<span class="result-price">$5990</span>',
#  u'<span class="result-price">$14750</span>',
#  u'<span class="result-price">$8000</span>',
#  u'<span class="result-price">$8000</span>',
#  u'<span class="result-price">$8500</span>',
#  u'<span class="result-price">$2500</span>',
#  u'<span class="result-price">$4500</span>',
#  u'<span class="result-price">$14800</span>',
#  u'<span class="result-price">$13000</span>',
#  u'<span class="result-price">$27950</span>',
#  u'<span class="result-price">$100</span>',
#  u'<span class="result-price">$12500</span>',
#  u'<span class="result-price">$5900</span>',
#  u'<span class="result-price">$8800</span>',
#  u'<span class="result-price">$14900</span>',
#  u'<span class="result-price">$25000</span>',
#  u'<span class="result-price">$29999</span>',
#  u'<span class="result-price">$1500</span>',
#  u'<span class="result-price">$34995</span>',
#  u'<span class="result-price">$6500</span>',
#  u'<span class="result-price">$33500</span>',
#  u'<span class="result-price">$33500</span>',
#  u'<span class="result-price">$62500</span>',
#  u'<span class="result-price">$18500</span>',
#  u'<span class="result-price">$15000</span>',
#  u'<span class="result-price">$17995</span>',
#  u'<span class="result-price">$8000</span>',
#  u'<span class="result-price">$5900</span>',
#  u'<span class="result-price">$2000</span>',
#  u'<span class="result-price">$22800</span>',
#  u'<span class="result-price">$30000</span>',
#  u'<span class="result-price">$19000</span>',
#  u'<span class="result-price">$2000</span>',
#  u'<span class="result-price">$23999</span>',
#  u'<span class="result-price">$27000</span>',
#  u'<span class="result-price">$7800</span>',
#  u'<span class="result-price">$120000</span>',
#  u'<span class="result-price">$24900</span>',
#  u'<span class="result-price">$13800</span>',
#  u'<span class="result-price">$13800</span>',
#  u'<span class="result-price">$14900</span>',
#  u'<span class="result-price">$69000</span>',
#  u'<span class="result-price">$44000</span>',
#  u'<span class="result-price">$200</span>',
#  u'<span class="result-price">$26955</span>',
#  u'<span class="result-price">$4500</span>',
#  u'<span class="result-price">$28999</span>',
#  u'<span class="result-price">$24000</span>',
#  u'<span class="result-price">$9500</span>',
#  u'<span class="result-price">$16000</span>',
#  u'<span class="result-price">$16500</span>',
#  u'<span class="result-price">$59995</span>',
#  u'<span class="result-price">$28900</span>',
#  u'<span class="result-price">$9995</span>',
#  u'<span class="result-price">$5800</span>',
#  u'<span class="result-price">$6500</span>',
#  u'<span class="result-price">$12000</span>',
#  u'<span class="result-price">$4500</span>',
#  u'<span class="result-price">$9995</span>',
#  u'<span class="result-price">$11500</span>',
#  u'<span class="result-price">$47000</span>']

# %%
Selector(text=HTML).xpath('//p/a/@href').extract()
# Out:
# [u'/eby/rvs/6178099805.html',
#  u'/nby/rvs/6188098678.html',
#  u'/nby/rvs/6188098381.html',
#  u'/sfc/rvs/6184813462.html',
#  u'/pen/rvs/6188087232.html',
#  u'/sby/rvs/6188072055.html',
#  u'/nby/rvd/6186581416.html',
#  u'/nby/rvs/6180906524.html',
#  u'/nby/rvs/6171517396.html',
#  u'/nby/rvs/6176267890.html',
#  u'/eby/rvs/6188012028.html',
#  u'/nby/rvs/6178005392.html',
#  u'/sfc/rvs/6187948022.html',
#  u'/nby/rvs/6188004876.html',
#  u'/sby/rvs/6184580435.html',
#  u'/sby/rvs/6146934904.html',
#  u'/sby/rvs/6157370653.html',
#  u'/nby/rvs/6181276736.html',
#  u'/sfc/rvs/6187966006.html',
#  u'/nby/rvs/6174207787.html',
#  u'/eby/rvs/6182476403.html',
#  u'/eby/rvs/6181149130.html',
#  u'/sby/rvs/6163638518.html',
#  u'/scz/rvs/6187955349.html',
#  u'/sby/rvs/6187934673.html',
#  u'/sby/rvs/6174860941.html',
#  u'/eby/rvs/6183262137.html',
#  u'/nby/rvs/6183649607.html',
#  u'/nby/rvs/6187909393.html',
#  u'/sfc/rvs/6183077985.html',
#  u'/sby/rvs/6180759925.html',
#  u'/nby/rvs/6183174592.html',
#  u'/nby/rvs/6187714129.html',
#  u'/sfc/rvs/6187730438.html',
#  u'/sfc/rvs/6187724540.html',
#  u'/sby/rvs/6187688286.html',
#  u'/eby/rvs/6162904470.html',
#  u'/sby/rvs/6187630771.html',
#  u'/sfc/rvs/6183867877.html',
#  u'/sfc/rvs/6183868894.html',
#  u'/eby/rvs/6187624514.html',
#  u'/eby/rvs/6187606072.html',
#  u'/pen/rvs/6187601740.html',
#  u'/eby/rvs/6187586292.html',
#  u'/eby/rvs/6156868155.html',
#  u'/scz/rvs/6187509930.html',
#  u'/eby/rvs/6187531755.html',
#  u'/nby/rvs/6183905718.html',
#  u'/scz/rvs/6153193936.html',
#  u'/scz/rvs/6168767536.html',
#  u'/scz/rvs/6173571521.html',
#  u'/sby/rvs/6178205577.html',
#  u'/sby/rvs/6178204060.html',
#  u'/sby/rvs/6187504268.html',
#  u'/nby/rvs/6187502117.html',
#  u'/pen/rvs/6187498297.html',
#  u'/sfc/rvs/6183535416.html',
#  u'/nby/rvs/6187475296.html',
#  u'/eby/rvs/6178340373.html',
#  u'/eby/rvs/6187469386.html',
#  u'/sby/rvs/6187466756.html',
#  u'/nby/rvs/6187463823.html',
#  u'/sby/rvs/6187461218.html',
#  u'/eby/rvs/6184415367.html',
#  u'/nby/rvs/6184181607.html',
#  u'/eby/rvs/6182919612.html',
#  u'/eby/rvs/6182552348.html',
#  u'/sby/rvs/6183959523.html',
#  u'/sfc/rvs/6180291479.html',
#  u'/eby/rvs/6183367351.html',
#  u'/sfc/rvs/6187377828.html',
#  u'/nby/rvs/6187398985.html',
#  u'/sby/rvs/6187396534.html',
#  u'/sby/rvs/6187375471.html',
#  u'/eby/rvs/6158264830.html',
#  u'/sby/rvs/6149608484.html',
#  u'/nby/rvs/6187366171.html',
#  u'/eby/rvd/6187346724.html',
#  u'/scz/rvs/6187294198.html',
#  u'/sfc/rvs/6177223318.html',
#  u'/sby/rvs/6177220977.html',
#  u'/sby/rvs/6187300110.html',
#  u'/eby/rvs/6177697808.html',
#  u'/sby/rvs/6187296039.html',
#  u'/eby/rvd/6187294451.html',
#  u'/scz/rvs/6187291031.html',
#  u'/eby/rvs/6187281914.html',
#  u'/nby/rvs/6187277485.html',
#  u'/sfc/rvs/6187276975.html',
#  u'/sby/rvs/6155656397.html',
#  u'/eby/rvs/6187271625.html',
#  u'/scz/rvs/6187266799.html',
#  u'/eby/rvs/6187265056.html',
#  u'/nby/rvs/6163953273.html',
#  u'/sfc/rvs/6187256750.html',
#  u'/sfc/rvs/6187241859.html',
#  u'/eby/rvs/6187240212.html',
#  u'/nby/rvs/6187238717.html',
#  u'/nby/rvs/6187238257.html',
#  u'/eby/rvs/6184129648.html',
#  u'/sby/rvs/6168422335.html',
#  u'/sby/rvs/6187232273.html',
#  u'/eby/rvs/6187225643.html',
#  u'/sfc/rvs/6187215960.html',
#  u'/pen/rvs/6187212243.html',
#  u'/sby/rvs/6171109620.html',
#  u'/sfc/rvs/6187207751.html',
#  u'/sby/rvs/6187207597.html',
#  u'/sby/rvs/6187195166.html',
#  u'/nby/rvs/6180735712.html',
#  u'/eby/rvd/6187179393.html',
#  u'/sfc/rvd/6187174695.html',
#  u'/eby/rvd/6187173302.html',
#  u'/eby/rvs/6187013227.html',
#  u'/nby/rvs/6175047786.html',
#  u'/sby/rvs/6175978165.html',
#  u'/eby/rvs/6187134899.html',
#  u'/eby/rvs/6187119926.html',
#  u'/nby/rvs/6187101748.html',
#  u'/nby/rvs/6187101089.html']

# %%
city = [r.encode('utf-8') for r in city]

# %%
city = [i.replace(" ", "") for i in city]

# %%
city
# Out:
# ['NewYork',
#  'LosAngeles',
#  'Chicago',
#  'Houston',
#  'Philadelphia',
#  'SanAntonio',
#  'SanDiego',
#  'Dallas',
#  'SanJose',
#  'Jacksonville',
#  'SanFrancisco',
#  'FortWorth',
#  'Charlotte',
#  'Seattle',
#  'ElPaso',
#  'Detroit',
#  'Memphis',
#  'Portland',
#  'LasVegas',
#  'Louisville',
#  'Baltimore',
#  'Milwaukee',
#  'Albuquerque',
#  'Tucson',
#  'Fresno',
#  'Mesa',
#  'KansasCity',
#  'LongBeach',
#  'ColoradoSprings',
#  'Miami',
#  'VirginiaBeach',
#  'Omaha',
#  'Oakland',
#  'Minneapolis',
#  'Tulsa',
#  'Arlington',
#  'NewOrleans',
#  'Wichita',
#  'Cleveland',
#  'Tampa',
#  'Bakersfield',
#  'Aurora',
#  'Anaheim',
#  'SantaAna',
#  'CorpusChristi',
#  'Riverside',
#  'Lexington',
#  'St.Louis',
#  'Stockton',
#  'Pittsburgh',
#  'Cincinnati',
#  'Anchorage',
#  'Henderson',
#  'Greensboro',
#  'Plano',
#  'Newark',
#  'Toledo',
#  'Orlando',
#  'ChulaVista',
#  'Irvine',
#  'FortWayne',
#  'JerseyCity',
#  'Durham',
#  'St.Petersburg',
#  'Laredo',
#  'Buffalo',
#  'Lubbock',
#  'Chandler',
#  'Scottsdale',
#  'Glendale',
#  'Reno',
#  'Norfolk',
#  'Winston\xe2\x80\x93Salem',
#  'NorthLasVegas',
#  'Irving',
#  'Chesapeake',
#  'Gilbert',
#  'Hialeah',
#  'Garland',
#  'Fremont',
#  'SanBernardino',
#  'Spokane',
#  'Modesto',
#  'Birmingham',
#  'Tacoma',
#  'Fontana',
#  'Rochester',
#  'Oxnard',
#  'MorenoValley',
#  'Fayetteville',
#  'Aurora',
#  'Glendale',
#  'Yonkers',
#  'HuntingtonBeach',
#  'Amarillo',
#  'Akron',
#  'Columbus',
#  'Augusta',
#  'GrandRapids',
#  'Shreveport',
#  'Huntsville',
#  'Mobile',
#  'GrandPrairie',
#  'OverlandPark',
#  'Knoxville',
#  'PortSt.Lucie',
#  'Worcester',
#  'Brownsville',
#  'Tempe',
#  'SantaClarita',
#  'NewportNews',
#  'CapeCoral',
#  'FortLauderdale',
#  'Chattanooga',
#  'RanchoCucamonga',
#  'Oceanside',
#  'SantaRosa',
#  'GardenGrove',
#  'Vancouver',
#  'SiouxFalls',
#  'Ontario',
#  'McKinney',
#  'ElkGrove',
#  'PembrokePines',
#  'Springfield',
#  'Corona',
#  'Eugene',
#  'FortCollins',
#  'Peoria',
#  'Frisco',
#  'Cary',
#  'Lancaster',
#  'Hayward',
#  'Palmdale',
#  'Salinas',
#  'Alexandria',
#  'Lakewood',
#  'Springfield',
#  'Pasadena',
#  'Sunnyvale',
#  'Macon',
#  'Pomona',
#  'Hollywood',
#  'KansasCity',
#  'Escondido',
#  'Clarksville',
#  'Joliet',
#  'Rockford',
#  'Torrance',
#  'Naperville',
#  'Paterson',
#  'Savannah',
#  'Bridgeport',
#  'Mesquite',
#  'Killeen',
#  'Syracuse',
#  'McAllen',
#  'Pasadena',
#  'Bellevue',
#  'Fullerton',
#  'Orange',
#  'Dayton',
#  'Miramar',
#  'Thornton',
#  'WestValleyCity',
#  'Olathe',
#  'Hampton',
#  'Warren',
#  'Midland',
#  'Waco',
#  'Charleston',
#  'Denton',
#  'Carrollton',
#  'Surprise',
#  'Roseville',
#  'SterlingHeights',
#  'Murfreesboro',
#  'Gainesville',
#  'CedarRapids',
#  'Visalia',
#  'CoralSprings',
#  'NewHaven',
#  'Stamford',
#  'ThousandOaks',
#  'Concord',
#  'Elizabeth',
#  'Lafayette',
#  'Kent',
#  'SimiValley',
#  'SantaClara',
#  'Athens',
#  'Victorville',
#  'Abilene',
#  'Norman',
#  'Vallejo',
#  'Berkeley',
#  'RoundRock',
#  'AnnArbor',
#  'Fargo',
#  'Columbia',
#  'Allentown',
#  'Evansville',
#  'Beaumont',
#  'Odessa',
#  'Wilmington',
#  'Arvada',
#  'Independence',
#  'Provo',
#  'ElMonte',
#  'Fairfield',
#  'Clearwater',
#  'Peoria',
#  'Rochester',
#  'Carlsbad',
#  'Westminster',
#  'WestJordan',
#  'Pearland',
#  'Richardson',
#  'Downey',
#  'MiamiGardens',
#  'Temecula',
#  'CostaMesa',
#  'CollegeStation',
#  'Elgin',
#  'Murrieta',
#  'Gresham',
#  'HighPoint',
#  'Antioch',
#  'Inglewood',
#  'Cambridge',
#  'Lowell',
#  'Manchester',
#  'Billings',
#  'Pueblo',
#  'PalmBay',
#  'Centennial',
#  'Richmond',
#  'Ventura',
#  'PompanoBeach',
#  'NorthCharleston',
#  'Everett',
#  'Waterbury',
#  'WestPalmBeach',
#  'Boulder',
#  'WestCovina',
#  'BrokenArrow',
#  'Clovis',
#  'DalyCity',
#  'Lakeland',
#  'SantaMaria',
#  'Norwalk',
#  'SandySprings',
#  'Hillsboro',
#  'GreenBay',
#  'Tyler',
#  'WichitaFalls',
#  'Lewisville',
#  'Burbank',
#  'Greeley',
#  'SanMateo',
#  'ElCajon',
#  'JurupaValley',
#  'Rialto',
#  'Davenport',
#  'LeagueCity',
#  'Edison',
#  'Davie',
#  'LasCruces',
#  'SouthBend',
#  'Vista',
#  'Woodbridge',
#  'Renton',
#  'Lakewood',
#  'SanAngelo',
#  'Clinton',
#  'Bayam\xc3\xb3n',
#  'Carolina',
#  'Ponce',
#  'Caguas',
#  'Nevada',
#  'Virginia',
#  'Nevada',
#  'Nevada',
#  'Louisiana',
#  'California',
#  'Nevada',
#  'Florida',
#  'NewYork',
#  'Pennsylvania',
#  'NewYork',
#  'NewJersey',
#  'Ohio',
#  'Michigan',
#  'Minnesota',
#  'Pennsylvania',
#  'Massachusetts',
#  'Michigan',
#  'Indiana',
#  'Indiana',
#  'Wisconsin',
#  'Michigan',
#  'Massachusetts',
#  'Massachusetts',
#  'NewYork',
#  'Ohio',
#  'Virginia',
#  'Pennsylvania',
#  'Virginia',
#  'Pennsylvania',
#  'Massachusetts',
#  'Missouri',
#  'NewJersey',
#  'NewYork',
#  'Delaware',
#  'Ohio']

# %%
def wrapper(f):
    def fun(l):
        # complete the function
        for item in l:
            f('http://{}.craigslist.org/search/rva?min_price=100'.format(item))
    return fun

@wrapper
def sort_list(l):
    print l

sort_list(city)
# Out:
# http://NewYork.craigslist.org/search/rva?min_price=100
# http://LosAngeles.craigslist.org/search/rva?min_price=100
# http://Chicago.craigslist.org/search/rva?min_price=100
# http://Houston.craigslist.org/search/rva?min_price=100
# http://Philadelphia.craigslist.org/search/rva?min_price=100
# http://SanAntonio.craigslist.org/search/rva?min_price=100
# http://SanDiego.craigslist.org/search/rva?min_price=100
# http://Dallas.craigslist.org/search/rva?min_price=100
# http://SanJose.craigslist.org/search/rva?min_price=100
# http://Jacksonville.craigslist.org/search/rva?min_price=100
# http://SanFrancisco.craigslist.org/search/rva?min_price=100
# http://FortWorth.craigslist.org/search/rva?min_price=100
# http://Charlotte.craigslist.org/search/rva?min_price=100
# http://Seattle.craigslist.org/search/rva?min_price=100
# http://ElPaso.craigslist.org/search/rva?min_price=100
# http://Detroit.craigslist.org/search/rva?min_price=100
# http://Memphis.craigslist.org/search/rva?min_price=100
# http://Portland.craigslist.org/search/rva?min_price=100
# http://LasVegas.craigslist.org/search/rva?min_price=100
# http://Louisville.craigslist.org/search/rva?min_price=100
# http://Baltimore.craigslist.org/search/rva?min_price=100
# http://Milwaukee.craigslist.org/search/rva?min_price=100
# http://Albuquerque.craigslist.org/search/rva?min_price=100
# http://Tucson.craigslist.org/search/rva?min_price=100
# http://Fresno.craigslist.org/search/rva?min_price=100
# http://Mesa.craigslist.org/search/rva?min_price=100
# http://KansasCity.craigslist.org/search/rva?min_price=100
# http://LongBeach.craigslist.org/search/rva?min_price=100
# http://ColoradoSprings.craigslist.org/search/rva?min_price=100
# http://Miami.craigslist.org/search/rva?min_price=100
# http://VirginiaBeach.craigslist.org/search/rva?min_price=100
# http://Omaha.craigslist.org/search/rva?min_price=100
# http://Oakland.craigslist.org/search/rva?min_price=100
# http://Minneapolis.craigslist.org/search/rva?min_price=100
# http://Tulsa.craigslist.org/search/rva?min_price=100
# http://Arlington.craigslist.org/search/rva?min_price=100
# http://NewOrleans.craigslist.org/search/rva?min_price=100
# http://Wichita.craigslist.org/search/rva?min_price=100
# http://Cleveland.craigslist.org/search/rva?min_price=100
# http://Tampa.craigslist.org/search/rva?min_price=100
# http://Bakersfield.craigslist.org/search/rva?min_price=100
# http://Aurora.craigslist.org/search/rva?min_price=100
# http://Anaheim.craigslist.org/search/rva?min_price=100
# http://SantaAna.craigslist.org/search/rva?min_price=100
# http://CorpusChristi.craigslist.org/search/rva?min_price=100
# http://Riverside.craigslist.org/search/rva?min_price=100
# http://Lexington.craigslist.org/search/rva?min_price=100
# http://St.Louis.craigslist.org/search/rva?min_price=100
# http://Stockton.craigslist.org/search/rva?min_price=100
# http://Pittsburgh.craigslist.org/search/rva?min_price=100
# http://Cincinnati.craigslist.org/search/rva?min_price=100
# http://Anchorage.craigslist.org/search/rva?min_price=100
# http://Henderson.craigslist.org/search/rva?min_price=100
# http://Greensboro.craigslist.org/search/rva?min_price=100
# http://Plano.craigslist.org/search/rva?min_price=100
# http://Newark.craigslist.org/search/rva?min_price=100
# http://Toledo.craigslist.org/search/rva?min_price=100
# http://Orlando.craigslist.org/search/rva?min_price=100
# http://ChulaVista.craigslist.org/search/rva?min_price=100
# http://Irvine.craigslist.org/search/rva?min_price=100
# http://FortWayne.craigslist.org/search/rva?min_price=100
# http://JerseyCity.craigslist.org/search/rva?min_price=100
# http://Durham.craigslist.org/search/rva?min_price=100
# http://St.Petersburg.craigslist.org/search/rva?min_price=100
# http://Laredo.craigslist.org/search/rva?min_price=100
# http://Buffalo.craigslist.org/search/rva?min_price=100
# http://Lubbock.craigslist.org/search/rva?min_price=100
# http://Chandler.craigslist.org/search/rva?min_price=100
# http://Scottsdale.craigslist.org/search/rva?min_price=100
# http://Glendale.craigslist.org/search/rva?min_price=100
# http://Reno.craigslist.org/search/rva?min_price=100
# http://Norfolk.craigslist.org/search/rva?min_price=100
# http://Winston–Salem.craigslist.org/search/rva?min_price=100
# http://NorthLasVegas.craigslist.org/search/rva?min_price=100
# http://Irving.craigslist.org/search/rva?min_price=100
# http://Chesapeake.craigslist.org/search/rva?min_price=100
# http://Gilbert.craigslist.org/search/rva?min_price=100
# http://Hialeah.craigslist.org/search/rva?min_price=100
# http://Garland.craigslist.org/search/rva?min_price=100
# http://Fremont.craigslist.org/search/rva?min_price=100
# http://SanBernardino.craigslist.org/search/rva?min_price=100
# http://Spokane.craigslist.org/search/rva?min_price=100
# http://Modesto.craigslist.org/search/rva?min_price=100
# http://Birmingham.craigslist.org/search/rva?min_price=100
# http://Tacoma.craigslist.org/search/rva?min_price=100
# http://Fontana.craigslist.org/search/rva?min_price=100
# http://Rochester.craigslist.org/search/rva?min_price=100
# http://Oxnard.craigslist.org/search/rva?min_price=100
# http://MorenoValley.craigslist.org/search/rva?min_price=100
# http://Fayetteville.craigslist.org/search/rva?min_price=100
# http://Aurora.craigslist.org/search/rva?min_price=100
# http://Glendale.craigslist.org/search/rva?min_price=100
# http://Yonkers.craigslist.org/search/rva?min_price=100
# http://HuntingtonBeach.craigslist.org/search/rva?min_price=100
# http://Amarillo.craigslist.org/search/rva?min_price=100
# http://Akron.craigslist.org/search/rva?min_price=100
# http://Columbus.craigslist.org/search/rva?min_price=100
# http://Augusta.craigslist.org/search/rva?min_price=100
# http://GrandRapids.craigslist.org/search/rva?min_price=100
# http://Shreveport.craigslist.org/search/rva?min_price=100
# http://Huntsville.craigslist.org/search/rva?min_price=100
# http://Mobile.craigslist.org/search/rva?min_price=100
# http://GrandPrairie.craigslist.org/search/rva?min_price=100
# http://OverlandPark.craigslist.org/search/rva?min_price=100
# http://Knoxville.craigslist.org/search/rva?min_price=100
# http://PortSt.Lucie.craigslist.org/search/rva?min_price=100
# http://Worcester.craigslist.org/search/rva?min_price=100
# http://Brownsville.craigslist.org/search/rva?min_price=100
# http://Tempe.craigslist.org/search/rva?min_price=100
# http://SantaClarita.craigslist.org/search/rva?min_price=100
# http://NewportNews.craigslist.org/search/rva?min_price=100
# http://CapeCoral.craigslist.org/search/rva?min_price=100
# http://FortLauderdale.craigslist.org/search/rva?min_price=100
# http://Chattanooga.craigslist.org/search/rva?min_price=100
# http://RanchoCucamonga.craigslist.org/search/rva?min_price=100
# http://Oceanside.craigslist.org/search/rva?min_price=100
# http://SantaRosa.craigslist.org/search/rva?min_price=100
# http://GardenGrove.craigslist.org/search/rva?min_price=100
# http://Vancouver.craigslist.org/search/rva?min_price=100
# http://SiouxFalls.craigslist.org/search/rva?min_price=100
# http://Ontario.craigslist.org/search/rva?min_price=100
# http://McKinney.craigslist.org/search/rva?min_price=100
# http://ElkGrove.craigslist.org/search/rva?min_price=100
# http://PembrokePines.craigslist.org/search/rva?min_price=100
# http://Springfield.craigslist.org/search/rva?min_price=100
# http://Corona.craigslist.org/search/rva?min_price=100
# http://Eugene.craigslist.org/search/rva?min_price=100
# http://FortCollins.craigslist.org/search/rva?min_price=100
# http://Peoria.craigslist.org/search/rva?min_price=100
# http://Frisco.craigslist.org/search/rva?min_price=100
# http://Cary.craigslist.org/search/rva?min_price=100
# http://Lancaster.craigslist.org/search/rva?min_price=100
# http://Hayward.craigslist.org/search/rva?min_price=100
# http://Palmdale.craigslist.org/search/rva?min_price=100
# http://Salinas.craigslist.org/search/rva?min_price=100
# http://Alexandria.craigslist.org/search/rva?min_price=100
# http://Lakewood.craigslist.org/search/rva?min_price=100
# http://Springfield.craigslist.org/search/rva?min_price=100
# http://Pasadena.craigslist.org/search/rva?min_price=100
# http://Sunnyvale.craigslist.org/search/rva?min_price=100
# http://Macon.craigslist.org/search/rva?min_price=100
# http://Pomona.craigslist.org/search/rva?min_price=100
# http://Hollywood.craigslist.org/search/rva?min_price=100
# http://KansasCity.craigslist.org/search/rva?min_price=100
# http://Escondido.craigslist.org/search/rva?min_price=100
# http://Clarksville.craigslist.org/search/rva?min_price=100
# http://Joliet.craigslist.org/search/rva?min_price=100
# http://Rockford.craigslist.org/search/rva?min_price=100
# http://Torrance.craigslist.org/search/rva?min_price=100
# http://Naperville.craigslist.org/search/rva?min_price=100
# http://Paterson.craigslist.org/search/rva?min_price=100
# http://Savannah.craigslist.org/search/rva?min_price=100
# http://Bridgeport.craigslist.org/search/rva?min_price=100
# http://Mesquite.craigslist.org/search/rva?min_price=100
# http://Killeen.craigslist.org/search/rva?min_price=100
# http://Syracuse.craigslist.org/search/rva?min_price=100
# http://McAllen.craigslist.org/search/rva?min_price=100
# http://Pasadena.craigslist.org/search/rva?min_price=100
# http://Bellevue.craigslist.org/search/rva?min_price=100
# http://Fullerton.craigslist.org/search/rva?min_price=100
# http://Orange.craigslist.org/search/rva?min_price=100
# http://Dayton.craigslist.org/search/rva?min_price=100
# http://Miramar.craigslist.org/search/rva?min_price=100
# http://Thornton.craigslist.org/search/rva?min_price=100
# http://WestValleyCity.craigslist.org/search/rva?min_price=100
# http://Olathe.craigslist.org/search/rva?min_price=100
# http://Hampton.craigslist.org/search/rva?min_price=100
# http://Warren.craigslist.org/search/rva?min_price=100
# http://Midland.craigslist.org/search/rva?min_price=100
# http://Waco.craigslist.org/search/rva?min_price=100
# http://Charleston.craigslist.org/search/rva?min_price=100
# http://Denton.craigslist.org/search/rva?min_price=100
# http://Carrollton.craigslist.org/search/rva?min_price=100
# http://Surprise.craigslist.org/search/rva?min_price=100
# http://Roseville.craigslist.org/search/rva?min_price=100
# http://SterlingHeights.craigslist.org/search/rva?min_price=100
# http://Murfreesboro.craigslist.org/search/rva?min_price=100
# http://Gainesville.craigslist.org/search/rva?min_price=100
# http://CedarRapids.craigslist.org/search/rva?min_price=100
# http://Visalia.craigslist.org/search/rva?min_price=100
# http://CoralSprings.craigslist.org/search/rva?min_price=100
# http://NewHaven.craigslist.org/search/rva?min_price=100
# http://Stamford.craigslist.org/search/rva?min_price=100
# http://ThousandOaks.craigslist.org/search/rva?min_price=100
# http://Concord.craigslist.org/search/rva?min_price=100
# http://Elizabeth.craigslist.org/search/rva?min_price=100
# http://Lafayette.craigslist.org/search/rva?min_price=100
# http://Kent.craigslist.org/search/rva?min_price=100
# http://SimiValley.craigslist.org/search/rva?min_price=100
# http://SantaClara.craigslist.org/search/rva?min_price=100
# http://Athens.craigslist.org/search/rva?min_price=100
# http://Victorville.craigslist.org/search/rva?min_price=100
# http://Abilene.craigslist.org/search/rva?min_price=100
# http://Norman.craigslist.org/search/rva?min_price=100
# http://Vallejo.craigslist.org/search/rva?min_price=100
# http://Berkeley.craigslist.org/search/rva?min_price=100
# http://RoundRock.craigslist.org/search/rva?min_price=100
# http://AnnArbor.craigslist.org/search/rva?min_price=100
# http://Fargo.craigslist.org/search/rva?min_price=100
# http://Columbia.craigslist.org/search/rva?min_price=100
# http://Allentown.craigslist.org/search/rva?min_price=100
# http://Evansville.craigslist.org/search/rva?min_price=100
# http://Beaumont.craigslist.org/search/rva?min_price=100
# http://Odessa.craigslist.org/search/rva?min_price=100
# http://Wilmington.craigslist.org/search/rva?min_price=100
# http://Arvada.craigslist.org/search/rva?min_price=100
# http://Independence.craigslist.org/search/rva?min_price=100
# http://Provo.craigslist.org/search/rva?min_price=100
# http://ElMonte.craigslist.org/search/rva?min_price=100
# http://Fairfield.craigslist.org/search/rva?min_price=100
# http://Clearwater.craigslist.org/search/rva?min_price=100
# http://Peoria.craigslist.org/search/rva?min_price=100
# http://Rochester.craigslist.org/search/rva?min_price=100
# http://Carlsbad.craigslist.org/search/rva?min_price=100
# http://Westminster.craigslist.org/search/rva?min_price=100
# http://WestJordan.craigslist.org/search/rva?min_price=100
# http://Pearland.craigslist.org/search/rva?min_price=100
# http://Richardson.craigslist.org/search/rva?min_price=100
# http://Downey.craigslist.org/search/rva?min_price=100
# http://MiamiGardens.craigslist.org/search/rva?min_price=100
# http://Temecula.craigslist.org/search/rva?min_price=100
# http://CostaMesa.craigslist.org/search/rva?min_price=100
# http://CollegeStation.craigslist.org/search/rva?min_price=100
# http://Elgin.craigslist.org/search/rva?min_price=100
# http://Murrieta.craigslist.org/search/rva?min_price=100
# http://Gresham.craigslist.org/search/rva?min_price=100
# http://HighPoint.craigslist.org/search/rva?min_price=100
# http://Antioch.craigslist.org/search/rva?min_price=100
# http://Inglewood.craigslist.org/search/rva?min_price=100
# http://Cambridge.craigslist.org/search/rva?min_price=100
# http://Lowell.craigslist.org/search/rva?min_price=100
# http://Manchester.craigslist.org/search/rva?min_price=100
# http://Billings.craigslist.org/search/rva?min_price=100
# http://Pueblo.craigslist.org/search/rva?min_price=100
# http://PalmBay.craigslist.org/search/rva?min_price=100
# http://Centennial.craigslist.org/search/rva?min_price=100
# http://Richmond.craigslist.org/search/rva?min_price=100
# http://Ventura.craigslist.org/search/rva?min_price=100
# http://PompanoBeach.craigslist.org/search/rva?min_price=100
# http://NorthCharleston.craigslist.org/search/rva?min_price=100
# http://Everett.craigslist.org/search/rva?min_price=100
# http://Waterbury.craigslist.org/search/rva?min_price=100
# http://WestPalmBeach.craigslist.org/search/rva?min_price=100
# http://Boulder.craigslist.org/search/rva?min_price=100
# http://WestCovina.craigslist.org/search/rva?min_price=100
# http://BrokenArrow.craigslist.org/search/rva?min_price=100
# http://Clovis.craigslist.org/search/rva?min_price=100
# http://DalyCity.craigslist.org/search/rva?min_price=100
# http://Lakeland.craigslist.org/search/rva?min_price=100
# http://SantaMaria.craigslist.org/search/rva?min_price=100
# http://Norwalk.craigslist.org/search/rva?min_price=100
# http://SandySprings.craigslist.org/search/rva?min_price=100
# http://Hillsboro.craigslist.org/search/rva?min_price=100
# http://GreenBay.craigslist.org/search/rva?min_price=100
# http://Tyler.craigslist.org/search/rva?min_price=100
# http://WichitaFalls.craigslist.org/search/rva?min_price=100
# http://Lewisville.craigslist.org/search/rva?min_price=100
# http://Burbank.craigslist.org/search/rva?min_price=100
# http://Greeley.craigslist.org/search/rva?min_price=100
# http://SanMateo.craigslist.org/search/rva?min_price=100
# http://ElCajon.craigslist.org/search/rva?min_price=100
# http://JurupaValley.craigslist.org/search/rva?min_price=100
# http://Rialto.craigslist.org/search/rva?min_price=100
# http://Davenport.craigslist.org/search/rva?min_price=100
# http://LeagueCity.craigslist.org/search/rva?min_price=100
# http://Edison.craigslist.org/search/rva?min_price=100
# http://Davie.craigslist.org/search/rva?min_price=100
# http://LasCruces.craigslist.org/search/rva?min_price=100
# http://SouthBend.craigslist.org/search/rva?min_price=100
# http://Vista.craigslist.org/search/rva?min_price=100
# http://Woodbridge.craigslist.org/search/rva?min_price=100
# http://Renton.craigslist.org/search/rva?min_price=100
# http://Lakewood.craigslist.org/search/rva?min_price=100
# http://SanAngelo.craigslist.org/search/rva?min_price=100
# http://Clinton.craigslist.org/search/rva?min_price=100
# http://Bayamón.craigslist.org/search/rva?min_price=100
# http://Carolina.craigslist.org/search/rva?min_price=100
# http://Ponce.craigslist.org/search/rva?min_price=100
# http://Caguas.craigslist.org/search/rva?min_price=100
# http://Nevada.craigslist.org/search/rva?min_price=100
# http://Virginia.craigslist.org/search/rva?min_price=100
# http://Nevada.craigslist.org/search/rva?min_price=100
# http://Nevada.craigslist.org/search/rva?min_price=100
# http://Louisiana.craigslist.org/search/rva?min_price=100
# http://California.craigslist.org/search/rva?min_price=100
# http://Nevada.craigslist.org/search/rva?min_price=100
# http://Florida.craigslist.org/search/rva?min_price=100
# http://NewYork.craigslist.org/search/rva?min_price=100
# http://Pennsylvania.craigslist.org/search/rva?min_price=100
# http://NewYork.craigslist.org/search/rva?min_price=100
# http://NewJersey.craigslist.org/search/rva?min_price=100
# http://Ohio.craigslist.org/search/rva?min_price=100
# http://Michigan.craigslist.org/search/rva?min_price=100
# http://Minnesota.craigslist.org/search/rva?min_price=100
# http://Pennsylvania.craigslist.org/search/rva?min_price=100
# http://Massachusetts.craigslist.org/search/rva?min_price=100
# http://Michigan.craigslist.org/search/rva?min_price=100
# http://Indiana.craigslist.org/search/rva?min_price=100
# http://Indiana.craigslist.org/search/rva?min_price=100
# http://Wisconsin.craigslist.org/search/rva?min_price=100
# http://Michigan.craigslist.org/search/rva?min_price=100
# http://Massachusetts.craigslist.org/search/rva?min_price=100
# http://Massachusetts.craigslist.org/search/rva?min_price=100
# http://NewYork.craigslist.org/search/rva?min_price=100
# http://Ohio.craigslist.org/search/rva?min_price=100
# http://Virginia.craigslist.org/search/rva?min_price=100
# http://Pennsylvania.craigslist.org/search/rva?min_price=100
# http://Virginia.craigslist.org/search/rva?min_price=100
# http://Pennsylvania.craigslist.org/search/rva?min_price=100
# http://Massachusetts.craigslist.org/search/rva?min_price=100
# http://Missouri.craigslist.org/search/rva?min_price=100
# http://NewJersey.craigslist.org/search/rva?min_price=100
# http://NewYork.craigslist.org/search/rva?min_price=100
# http://Delaware.craigslist.org/search/rva?min_price=100
# http://Ohio.craigslist.org/search/rva?min_price=100

# %% [markdown]
# ## 3. Define a function to caculate mean and median price per city.
#
# Now that you've created a list of cities you want to scrape, adapt your solution for grabbing data in one region site, to grab data for all regional sites that you collected, then calculate the mean and median price of RV results from each city.
#
# > Look at the URLs from a few different regions (ie: portland, phoenix, sfbay), and find what they have in common.  Determine the area in the URL string that needs to change the least, and figure out how to replace only that portion of the URL in order to iterate through each city.

# %% [markdown]
# ## 4. Run your scraping process, and save your results to a CSV file.

# %% [markdown]
# ## 5. Do an analysis of the RV market.
#
# Go head we'll wait.  Anything notable about the data?

# %%
rvsf_df = pd.read_csv('/Users/keatoncarano/Desktop/dsi-sf-7-materials-Keaton/craigslist/craigslist/craigslist/spiders/sfrv.csv')
rvsf_df[['price']] = rvsf_df[['price']].replace('[\$,]','',regex=True).astype(float)

# %%
rvpr_df = pd.read_csv('/Users/keatoncarano/Desktop/dsi-sf-7-materials-Keaton/craigslist/craigslist/craigslist/spiders/cl_crawl_port2.csv')
rvpr_df[['price']] = rvpr_df[['price']].replace('[\$,]','',regex=True).astype(float)

# %%
rvsf_df.head()
# Out:
#       price                                               link  \
# 0   11999.0  https://sfbay.craigslist.org/nby/rvd/618710067...
# 1   25000.0  https://sfbay.craigslist.org/sby/rvs/617674163...
# 2  147900.0  https://sfbay.craigslist.org/sby/rvd/618708817...
# 3    5800.0  https://sfbay.craigslist.org/sfc/rvs/618704183...
# 4    9300.0  https://sfbay.craigslist.org/eby/rvs/618707407...
#
#                                              listing
# 0  SPECIAL - 2003 -  29 foot Arctic Fox Travel Tr...
# 1               2000 Winnebago 35ft Itasca 18k miles
# 2  2007 Monaco Camelot 42PDQ Quad Slide-Out Class...
# 3                   Hybrid Expandable Travel Trailer
# 4              2007 KEYSTONE SPRINGDALE USED 3 TIMES

# %%
#SF mean and Median Prices
print np.mean(rvsf_df.price), np.median(rvsf_df.price)
# Out:
# 31609.8108553 19900.0

# %%
sflisting = rvsf_df.groupby(['listing'])['price'].mean()

# %%
rvpr_df.head(3)
# Out:
#      price                                               link  \
# 0  89995.0  https://portland.craigslist.org/mlt/rvs/617235...
# 1    200.0  https://portland.craigslist.org/clc/rvs/615451...
# 2  89995.0  https://portland.craigslist.org/mlt/rvs/617235...
#
#                         listing
# 0  2007 Winnebago 36G Motorhome
# 1                  Tent Trailer
# 2  2007 Winnebago 36G Motorhome

# %%
sflisting.shape
# Out:
# (1072,)

# %%
rvpr_df.dropna()
# Out:
#          price                                               link  \
# 0      89995.0  https://portland.craigslist.org/mlt/rvs/617235...
# 1        200.0  https://portland.craigslist.org/clc/rvs/615451...
# 2      89995.0  https://portland.craigslist.org/mlt/rvs/617235...
# 3      89995.0  https://portland.craigslist.org/mlt/rvs/617221...
# 4      89995.0  https://portland.craigslist.org/mlt/rvs/617221...
# 5      89995.0  https://portland.craigslist.org/mlt/rvs/618033...
# 6       6500.0  https://portland.craigslist.org/wsc/rvs/618669...
# 7      65000.0  https://portland.craigslist.org/clc/rvs/615417...
# 8      34900.0  https://portland.craigslist.org/mlt/rvd/618667...
# 9      44900.0  https://portland.craigslist.org/mlt/rvd/618667...
# 10       200.0  https://portland.craigslist.org/mlt/rvs/618667...
# 11     31900.0  https://portland.craigslist.org/mlt/rvd/618667...
# 12       100.0  https://portland.craigslist.org/clk/rvs/618666...
# 13     49900.0  https://portland.craigslist.org/mlt/rvd/618666...
# 14     12988.0  https://portland.craigslist.org/mlt/rvd/618666...
# 15     25950.0  https://portland.craigslist.org/clc/rvs/618340...
# 16     18500.0  https://portland.craigslist.org/clc/rvs/618664...
# 17      6000.0  https://portland.craigslist.org/mlt/rvs/618662...
# 18       100.0  https://portland.craigslist.org/clk/rvs/618664...
# 19    109950.0  https://portland.craigslist.org/clk/rvd/618664...
# 20       375.0  https://portland.craigslist.org/clk/rvs/617288...
# 21     20000.0  https://portland.craigslist.org/mlt/rvs/617696...
# 22     59800.0  https://portland.craigslist.org/clc/rvs/618663...
# 23      3400.0  https://portland.craigslist.org/grg/rvs/618661...
# 24       600.0  https://portland.craigslist.org/clk/rvs/618661...
# 25     24995.0  https://portland.craigslist.org/mlt/rvd/618660...
# 26     33995.0  https://portland.craigslist.org/mlt/rvd/618660...
# 27     20995.0  https://portland.craigslist.org/mlt/rvd/618659...
# 28     19995.0  https://portland.craigslist.org/mlt/rvd/618659...
# 29     15000.0  https://portland.craigslist.org/clk/rvs/617080...
# ...        ...                                                ...
# 2186   45999.0  https://portland.craigslist.org/clk/rvd/614351...
# 2187   24344.0  https://portland.craigslist.org/mlt/rvd/614351...
# 2188   42500.0  https://portland.craigslist.org/clk/rvd/614350...
# 2189   34550.0  https://portland.craigslist.org/clk/rvd/614350...
# 2190   17999.0  https://portland.craigslist.org/mlt/rvd/614349...
# 2191   42995.0  https://portland.craigslist.org/clc/rvd/614345...
# 2192   15995.0  https://portland.craigslist.org/wsc/rvd/614337...
# 2193   13500.0  https://portland.craigslist.org/clk/rvd/614335...
# 2194   57500.0  https://portland.craigslist.org/clk/rvd/614334...
# 2195   14900.0  https://portland.craigslist.org/clk/rvd/614331...
# 2196   20995.0  https://portland.craigslist.org/mlt/rvd/614330...
# 2197   33995.0  https://portland.craigslist.org/mlt/rvd/614330...
# 2198   28995.0  https://portland.craigslist.org/mlt/rvd/614330...
# 2199   20995.0  https://portland.craigslist.org/mlt/rvd/614329...
# 2200   11999.0  https://portland.craigslist.org/clc/rvd/614328...
# 2201  149950.0  https://portland.craigslist.org/clk/rvd/614326...
# 2202     199.0  https://portland.craigslist.org/mlt/rvd/614314...
# 2203  119999.0  https://portland.craigslist.org/mlt/rvd/614313...
# 2204   49999.0  https://portland.craigslist.org/clk/rvd/614310...
# 2205   59999.0  https://portland.craigslist.org/mlt/rvd/614305...
# 2206   49995.0  https://portland.craigslist.org/mlt/rvd/614302...
# 2207   17745.0  https://portland.craigslist.org/wsc/rvd/614299...
# 2208    6995.0  https://portland.craigslist.org/wsc/rvd/614299...
# 2209   18499.0  https://portland.craigslist.org/mlt/rvd/614298...
# 2210   16995.0  https://portland.craigslist.org/mlt/rvd/614292...
# 2211   39995.0  https://portland.craigslist.org/wsc/rvd/614287...
# 2212   99950.0  https://portland.craigslist.org/clk/rvd/614283...
# 2213   17950.0  https://portland.craigslist.org/clc/rvd/614267...
# 2214   25355.0  https://portland.craigslist.org/clk/rvd/614238...
# 2215    7475.0  https://portland.craigslist.org/mlt/rvs/582214...
#
#                                                 listing
# 0                          2007 Winnebago 36G Motorhome
# 1                                          Tent Trailer
# 2                          2007 Winnebago 36G Motorhome
# 3                          2007 Winnebago 36G Motorhome
# 4                          2007 Winnebago 36G Motorhome
# 5                          2007 Winnebago 36G Motorhome
# 6                                      Clean class C!!!
# 7     Camper/Truck F450 2008 Lariat diesel and 2012 ...
# 8     2005 Coachmen Freedom Ramp & Camp 30' Class C ...
# 9                       2008 Dorado B+ 26' Double Slide
# 10    Reese (Tow Tite) equalizer 10,000lb trailer hitch
# 11                     2002 Kodiak  B+ 22' Single Slide
# 12                              camper trailer for rent
# 13    2003 Itasca Horizon  40' *Diesel Pusher * Doub...
# 14            NEW 2017 CARGOPRO X-SERIES CHECK THIS OUT
# 15                 *Toy Hauler Travel Trailer for Sale*
# 16              2015 Surveyor 240RBS - Exterior Kitchen
# 17                                   2004 Prowler  Lite
# 18                                     RV Cover 30-33ft
# 19    2008 HOLIDAY RAMBLER AMBASSADOR SUPER FLOOR PL...
# 20               5th wheel hitch slider . dropped price
# 21                                  Sunnybrook Titan RV
# 22               2007 fleetwood  34N FIESTA LX. CLASS A
# 23         1993 Jayco Eagle Series 5th Wheel RV Trailer
# 24                                      5TH WHEEL HITCH
# 25                        00 Allegro 26     *30K Miles*
# 26                       03 Minnie 31       *Slide-Out*
# 27             00 Flair 30                 *35K Miles**
# 28                             2016 Rockwood Mini 1809S
# 29           1976 Prevost Prestige premier mh/party bus
# ...                                                 ...
# 2186             2018 FOREST RIVER WILDCAT MAXX F262RGX
# 2187                    2017 Forest River Sonoma 240RBK
# 2188                            2012 Heartland Sundance
# 2189                             213 Coachmen Chaparral
# 2190                     2018 Forest River Sonoma 167RB
# 2191  2007 Monaco Monarch 30' Class A only 21K Miles...
# 2192      New 2017 Rockwood A213HW Folding Camp Trailer
# 2193                           1992 Fleetwood Southwind
# 2194                          2007 Four Winds Hurricane
# 2195                           1996 Newmar Kountry Star
# 2196                   99 Rexair 29         *30K Miles*
# 2197                     03 Minnie 31       *Slide-Out*
# 2198             00 Winnebago Cheiftain 34  *36K Miles*
# 2199           00 Flair 30                 *35K Miles**
# 2200                  2004 Keystone Sprinter 29' 274RLS
# 2201  2008 NEWMAR DUTCH STAR 425-HP DIESEL WARRANTY ...
# 2202  Big Sale on Weight Distribution /anti sway hit...
# 2203                       2015 Roadtrek Adventurous TS
# 2204              2018 FOREST RIVER WILDCAT MAXX T32TSX
# 2205                           2011 Jayco Greyhawk 31SS
# 2206  Used RVs 2011 COACHMAN STONEBROOK 324RL FIFTH ...
# 2207  2017 TRAVEL LITE FALCON F-20 light Trailer for...
# 2208  1999 nash 5Th wheel model 21-5r ready for your...
# 2209  Light Weight! 2015 Heartland North Trail 28BRS...
# 2210  2007 NORTHSTAR TS1000 USED RVS LONG BED PICKUP...
# 2211         New 2017 Bigfoot RV 25B21FB Travel Trailer
# 2212  2006 HR ENDEAVOR 400-HP DIESEL 4 SLIDES STACK ...
# 2213      *****2016 WINNEBAGO TRAILER W/SLIDE  27'*****
# 2214                   2017 KEYSTONE RV HIDEOUT 23RKSWE
# 2215  Pop up Truck Camper 2004 Northstar TC800 (rent...
#
# [2216 rows x 3 columns]

# %%
np.mean(rvpr_df['price'])
# Out:
# 31847.466606498194

# %%
#portland mean and median prices

print np.mean(rvpr_df.price), np.median(rvpr_df.price)
# Out:
# 31847.4666065 19995.0

# %%
rvsf_df['city'] = 'sfbayarea'

# %%
rvpr_df['city'] = 'portland'

# %%
rvpr_df.head()
# Out:
#      price                                               link  \
# 0  89995.0  https://portland.craigslist.org/mlt/rvs/617235...
# 1    200.0  https://portland.craigslist.org/clc/rvs/615451...
# 2  89995.0  https://portland.craigslist.org/mlt/rvs/617235...
# 3  89995.0  https://portland.craigslist.org/mlt/rvs/617221...
# 4  89995.0  https://portland.craigslist.org/mlt/rvs/617221...
#
#                         listing      city
# 0  2007 Winnebago 36G Motorhome  portland
# 1                  Tent Trailer  portland
# 2  2007 Winnebago 36G Motorhome  portland
# 3  2007 Winnebago 36G Motorhome  portland
# 4  2007 Winnebago 36G Motorhome  portland

# %%
rv_all = pd.concat([rvsf_df, rvpr_df], ignore_index=True)

# %%
rv_all.head()
# Out:
#       price                                               link  \
# 0   11999.0  https://sfbay.craigslist.org/nby/rvd/618710067...
# 1   25000.0  https://sfbay.craigslist.org/sby/rvs/617674163...
# 2  147900.0  https://sfbay.craigslist.org/sby/rvd/618708817...
# 3    5800.0  https://sfbay.craigslist.org/sfc/rvs/618704183...
# 4    9300.0  https://sfbay.craigslist.org/eby/rvs/618707407...
#
#                                              listing       city
# 0  SPECIAL - 2003 -  29 foot Arctic Fox Travel Tr...  sfbayarea
# 1               2000 Winnebago 35ft Itasca 18k miles  sfbayarea
# 2  2007 Monaco Camelot 42PDQ Quad Slide-Out Class...  sfbayarea
# 3                   Hybrid Expandable Travel Trailer  sfbayarea
# 4              2007 KEYSTONE SPRINGDALE USED 3 TIMES  sfbayarea

# %% [markdown]
# ### 5.1 Does it makes sense to buy RVs in one region and sell them in another?
#
# Assuming the cost of shipping or driving from one regional market to another.

# %%
region = rv_all.groupby(['city'])['price'].mean()

# %%
region
# Out:
# city
# portland     31847.466606
# sfbayarea    31609.810855
# Name: price, dtype: float64

# %%
#it would appear as though you could buy a RV in the SF bay area and sell it for a profit in protland. However, this may just be 
# due to the RV's in portland being more expensive

# %% [markdown]
# ### 5.2 Can you pull out the "make" from the markup and include that in your analyis?
# How reliable is this data and does it make sense?

# %%
sflisting = rvsf_df.groupby(['listing'])['price'].mean()
#it is possible to pull this data from the description but it is essentially unstructured data and is 
#nearly impossible to sort. Because each craigslist poster is able to input the string however they want.
# when you look at the listing above, it is evident that almost all descriptions are unique as the total as the
#groupby only reduce the listing size by 100

#HOWEVER, if i was looking for a specific make or model, I would filter the pandas dataframe to look for that
#make / model in the description. Could also do multiple makes and models ect. However I do not know specifics
#about RVs


print sflisting.shape, rvsf_df['listing'].shape
# Out:
# (1072,) (1216,)

# %% [markdown]
# ### 5.3 Are there any other variables you could pull out of the markup to help describe your dataset?

# %%
#we could get more granular and attempt to look at surrounding cities to a major city to see if we could find the same 
#make and model except for a cheaper price. However, we would run into the issue of difficulty extracting the make
#and model info from the description

# %% [markdown]
# ## 6. Move your project into scrapy (if you haven't used Scrapy yet)
#
# >Start a project by using the command `scrapy startproject [projectname]`
# > - Update your settings.py (review our past example)
# > - Update your items.py
# > - Create a spiders file in your `[project_name]/[project_name]/spiders` directory
#
# You can update your spider class with the complete list of craigslist "start urls" to effectively scrape all of the regions.  Start with one to test.
#
# Updating your parse method with the method you chose should require minimal changes.  It will require you to update your parse method to use the response parameter, and an item model (defined in items.py).

# %%
#done

# %% [markdown]
# ## 7.  Chose another area of Craigslist to scrape.
#
# **Choose an area having more than a single page of results, then scrape multiple regions, multiple pages of search results and or details pages.**
#
# This is the true exercise of being able to understand how to succesffuly plan, develop, and employ a broader scraping strategy.  Even though this seems like a challenging task, a few tweeks of your current code can make this very managable if you've pieced together all the touch points.  If you are still confused as to some of the milestones within this process, this is an excellent opportunity to round out your understanding, or help you build a list of questions to fill in your gaps.
#
# _Use Scrapy!  Provide your code in this project directory when you submit this project._

# %%
#look at sf apartments between 2000 and 4000 in rent
sf_apt_r = requests.get('https://sfbay.craigslist.org/search/sfc/apa?min_price=2000&max_price=4000&availabilityMode=0')
HTML = sf_apt_r.text  
HTML[0:150]
# Out:
# u'\ufeff<!DOCTYPE html>\n\n<html class="no-js"><head>\n    <title>SF bay area apts/housing for rent  - craigslist</title>\n\n    <meta name="description" content='

# %%
#description
description = Selector(text=HTML).xpath('//p/a[@class="result-title hdrlnk"]/text()').extract()

# %%
#Pull rent per month
rent = Selector(text=HTML).xpath('//span[@class="result-meta"]/span[@class="result-price"]/text()').extract()

# %%
#pull neighborhood from each listing
hood = Selector(text=HTML).xpath('//span[@class="result-meta"]/span[@class="result-hood"]/text()').extract()

# %%
rooms = hood = Selector(text=HTML).xpath('//span[@class="result-meta"]/span[@class="housing"]/text()').extract()

# %% [markdown]
# I could then take all of these and put them into a pandas dataframe and then perform some analysis as well as cleaning of the data
