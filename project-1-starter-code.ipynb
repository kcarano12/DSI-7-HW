# %% [markdown]
# <img src="http://i.imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
#
# After reading the gushing praise for Pokemon Go you decide to download it and try it out for yourself. Yet a couple hours of play later you find yourself disappointed by the fact that you _actually_ have to move around outside.
#
# Though just a beginner programmer, you decide to make your own iteration on the genre: "Pokemon Stay". In this version players still need to move, but just from website to website. Pokemon gyms are now popular cyber-destinations, and catching pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# ---
#
# #### Package imports
#
# The `pprint` package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint

# %% [markdown]
# <img src=http://i.imgur.com/l5NasQj.png style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create a player. The dictionary and list variables should just be defined as empty at this point.

# %%
player1_id = 1
player1_name = "Brock"
time_played1 = 0.0
player1_pokemon = {}
gyms_visited1 = ['reddit.com', 'linkedin.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'udacity.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
# Example output:
# 
# ['amazon.com', 'ebay.com']
pokegyms = ['reddit.com', 'amazon.com', 'twitter.com', 'linked.com', 'ebay.com', 'netflix.com', 'udacity.com', 'stackoverflow.com', 'github.com', 'quora.com']
print pokegyms
# Out:
# ['reddit.com', 'amazon.com', 'twitter.com', 'linked.com', 'ebay.com', 'netflix.com', 'udacity.com', 'stackoverflow.com', 'github.com', 'quora.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print the pokedex dictionary with the 3 pokemon.

# %%
# No example output... too similar to the answer!

pokemon = {
    1:{
        'name': 'charmander',
        'type_p': 'fire',
        'hp': 35,
        'attack': 30,
        'defense': 20,
        'special_attack': 15,
        'special_defense': 20,
        'speed': 20
        
    },
    2:{
        'name': 'squirtle',
        'type_p': 'water',
        'hp': 35,
        'attack': 25,
        'defense': 25,
        'special_attack': 15,
        'special_defense': 15,
        'speed': 25
        
    },
    3:{
        'name': 'bulbasaur',
        'type_p': 'Grass',
        'hp': 40,
        'attack': 20,
        'defense': 30,
        'special_attack': 10,
        'special_defense': 25,
        'speed': 25
        
    } 
}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1). **The values in the player's dictionary will be the variables you assigned in question 1.**
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
# Example output from print:
#
# {1: {'gyms_visited': ['amazon.com', 'ebay.com'],
#      'player_name': 'Ash',
#      'player_pokemon': {},
#      'time_played': 0.0}}
# No example output. 
player2_id = 2
player2_name = "Gary"
time_played2 = 57.3
player2_pokemon = {}
gyms_visited2 = ['stackoverflow.com', 'github.com']

players = {
    1:{
        'gyms_visited': gyms_visited1,
        'player_name': player1_name,
        'player_pokemon': player1_pokemon,
        'time_played': time_played1
    },
    2:{
       'gyms_visited': gyms_visited2,
        'player_name': player2_name,
        'player_pokemon': player2_pokemon,
        'time_played': time_played2 
    }
}
print players
# Out:
# {1: {'time_played': 0.0, 'gyms_visited': ['reddit.com', 'linkedin.com'], 'player_name': 'Brock', 'player_pokemon': {}}, 2: {'time_played': 57.3, 'gyms_visited': ['stackoverflow.com', 'github.com'], 'player_name': 'Gary', 'player_pokemon': {}}}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'stackoverflow.com'` and `'github.com'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
# Example output from print:
#
# {1: {'gyms_visited': ['amazon.com', 'ebay.com'],
#      'player_name': 'Ash',
#      'player_pokemon': {2: ...squirtle dictionary...},
#      'time_played': 0.0},
#  2: {'gyms_visited': ['stackoverflow.com', 'github.com'],
#      'player_name': 'Brock',
#      'player_pokemon': {1: ...charmander dictionary..., 3: ...bulbasaur dictionary...},
#      'time_played': 10.0}}

player1_pokemon[2]=pokemon[2]
player2_pokemon[3]=pokemon[3]
player2_pokemon[1]=pokemon[1]
print players
# Out:
# {1: {'time_played': 0.0, 'gyms_visited': ['reddit.com', 'linkedin.com'], 'player_name': 'Brock', 'player_pokemon': {2: {'attack': 25, 'type_p': 'water', 'defense': 25, 'name': 'squirtle', 'special_attack': 15, 'hp': 35, 'speed': 25, 'special_defense': 15}}}, 2: {'time_played': 57.3, 'gyms_visited': ['stackoverflow.com', 'github.com'], 'player_name': 'Gary', 'player_pokemon': {1: {'attack': 30, 'type_p': 'fire', 'defense': 20, 'name': 'charmander', 'special_attack': 15, 'hp': 35, 'speed': 20, 'special_defense': 20}, 3: {'attack': 20, 'type_p': 'Grass', 'defense': 30, 'name': 'bulbasaur', 'special_attack': 10, 'hp': 40, 'speed': 25, 'special_defense': 25}}}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 6. What gyms have players visited?
#
# ---
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
# Example output:
#
# Ash has visited amazon.com.
# Ash has visited ebay.com.
# Ash has visited amazon.com.
# Brock has visited stackoverflow.com.
# Brock has visited github.com.
for player in players:
    for gym in players[player]['gyms_visited']:
        print players[player]['player_name'] + ' has visited ' + gym
# Out:
# Brock has visited reddit.com
# Brock has visited linkedin.com
# Gary has visited stackoverflow.com
# Gary has visited github.com

# %%
[players[player]['player_name'] + ' has visited ' + gym for player in players for gym in players[player]['gyms_visited']]
# Out:
# ['Brock has visited reddit.com',
#  'Brock has visited linkedin.com',
#  'Gary has visited stackoverflow.com',
#  'Gary has visited github.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %%
# Example output:
#
# Ash's power is 57.
# 57
# Brock's power is 119.
# 119
#poke_dict input is redundant because it is called the same thing for all players in my dictionary.

def power_calc(player_id):
    power = 0
    for stat in players[player_id]['player_pokemon'].values():
        for val in stat.values():
            try:
                power += val
            except:
                pass
    print players[player_id]['player_name'] + "'s power is " + str(power)
    return power

##### code the string !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
power_calc(2)
# Out:
# Gary's power is 290
# 290

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# Now we have access to the raw base stats on all of the pokemon, scraped from the web.
#
# The provided code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# The first three lists in your pokedex list should look like so:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
raw_pd = ''
pokedex_file = '/Users/keatoncarano/Desktop/dsi-sf-7-materials-Keaton/datasets/pokemon/pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.readlines()
    
# the pokedex string is assigned to the raw_pd variable

# %%
def create_pokedex(pd):
    new_pd = []
    for line in pd:
        line = line.replace('"','')
        line = line.rstrip('\n')
        line = line.split(",")
        for i, var in enumerate(line):
            try:
                if var == "":
                    line[i]==-1.0
                elif type(int(var)) == int:
                    line[i] = float(var)
            except:
                pass
            

            # you need to store var after the type conversion
            # do that here
        new_pd.append(line)
    return new_pd

# %%
pokedex_ls = create_pokedex(raw_pd)
print pokedex_ls
# Out:
# [['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed'], [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0], [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0], [3.0, 'Venusaur', 'GrassPoison', 525.0, 80.0, 82.0, 83.0, 100.0, 100.0, 80.0], [3.0, 'VenusaurMega Venusaur', 'GrassPoison', 625.0, 80.0, 100.0, 123.0, 122.0, 120.0, 80.0], [4.0, 'Charmander', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0], [5.0, 'Charmeleon', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0], [6.0, 'Charizard', 'FireFlying', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0], [6.0, 'CharizardMega Charizard X', 'FireDragon', 634.0, 78.0, 130.0, 111.0, 130.0, 85.0, 100.0], [6.0, 'CharizardMega Charizard Y', 'FireFlying', 634.0, 78.0, 104.0, 78.0, 159.0, 115.0, 100.0], [7.0, 'Squirtle', 'Water', 314.0, 44.0, 48.0, 65.0, 50.0, 64.0, 43.0], [8.0, 'Wartortle', 'Water', 405.0, 59.0, 63.0, 80.0, 65.0, 80.0, 58.0], [9.0, 'Blastoise', 'Water', 530.0, 79.0, 83.0, 100.0, 85.0, 105.0, 78.0], [9.0, 'BlastoiseMega Blastoise', 'Water', 630.0, 79.0, 103.0, 120.0, 135.0, 115.0, 78.0], [10.0, 'Caterpie', 'Bug', 195.0, 45.0, 30.0, 35.0, 20.0, 20.0, 45.0], [11.0, 'Metapod', 'Bug', 205.0, 50.0, 20.0, 55.0, 25.0, 25.0, 30.0], [12.0, 'Butterfree', 'BugFlying', 395.0, 60.0, 45.0, 50.0, 90.0, 80.0, 70.0], [13.0, 'Weedle', 'BugPoison', 195.0, 40.0, 35.0, 30.0, 20.0, 20.0, 50.0], [14.0, 'Kakuna', 'BugPoison', 205.0, 45.0, 25.0, 50.0, 25.0, 25.0, 35.0], [15.0, 'Beedrill', 'BugPoison', 395.0, 65.0, 90.0, 40.0, 45.0, 80.0, 75.0], [15.0, 'BeedrillMega Beedrill', 'BugPoison', 495.0, 65.0, 150.0, 40.0, 15.0, 80.0, 145.0], [16.0, 'Pidgey', 'NormalFlying', 251.0, 40.0, 45.0, 40.0, 35.0, 35.0, 56.0], [17.0, 'Pidgeotto', 'NormalFlying', 349.0, 63.0, 60.0, 55.0, 50.0, 50.0, 71.0], [18.0, 'Pidgeot', 'NormalFlying', 479.0, 83.0, 80.0, 75.0, 70.0, 70.0, 101.0], [18.0, 'PidgeotMega Pidgeot', 'NormalFlying', 579.0, 83.0, 80.0, 80.0, 135.0, 80.0, 121.0], [19.0, 'Rattata', 'Normal', 253.0, 30.0, 56.0, 35.0, 25.0, 35.0, 72.0], [20.0, 'Raticate', 'Normal', 413.0, 55.0, 81.0, 60.0, 50.0, 70.0, 97.0], [21.0, 'Spearow', 'NormalFlying', 262.0, 40.0, 60.0, 30.0, 31.0, 31.0, 70.0], [22.0, 'Fearow', 'NormalFlying', 442.0, 65.0, 90.0, 65.0, 61.0, 61.0, 100.0], [23.0, 'Ekans', 'Poison', 288.0, 35.0, 60.0, 44.0, 40.0, 54.0, 55.0], [24.0, 'Arbok', 'Poison', 438.0, 60.0, 85.0, 69.0, 65.0, 79.0, 80.0], [25.0, 'Pikachu', 'Electric', 320.0, 35.0, 55.0, 40.0, 50.0, 50.0, 90.0], [26.0, 'Raichu', 'Electric', 485.0, 60.0, 90.0, 55.0, 90.0, 80.0, 110.0], [27.0, 'Sandshrew', 'Ground', 300.0, 50.0, 75.0, 85.0, 20.0, 30.0, 40.0], [28.0, 'Sandslash', 'Ground', 450.0, 75.0, 100.0, 110.0, 45.0, 55.0, 65.0], [29.0, 'Nidoran\xe2\x99\x80', 'Poison', 275.0, 55.0, 47.0, 52.0, 40.0, 40.0, 41.0], [30.0, 'Nidorina', 'Poison', 365.0, 70.0, 62.0, 67.0, 55.0, 55.0, 56.0], [31.0, 'Nidoqueen', 'PoisonGround', 505.0, 90.0, 92.0, 87.0, 75.0, 85.0, 76.0], [32.0, 'Nidoran\xe2\x99\x82', 'Poison', 273.0, 46.0, 57.0, 40.0, 40.0, 40.0, 50.0], [33.0, 'Nidorino', 'Poison', 365.0, 61.0, 72.0, 57.0, 55.0, 55.0, 65.0], [34.0, 'Nidoking', 'PoisonGround', 505.0, 81.0, 102.0, 77.0, 85.0, 75.0, 85.0], [35.0, 'Clefairy', 'Fairy', 323.0, 70.0, 45.0, 48.0, 60.0, 65.0, 35.0], [36.0, 'Clefable', 'Fairy', 483.0, 95.0, 70.0, 73.0, 95.0, 90.0, 60.0], [37.0, 'Vulpix', 'Fire', 299.0, 38.0, 41.0, 40.0, 50.0, 65.0, 65.0], [38.0, 'Ninetales', 'Fire', 505.0, 73.0, 76.0, 75.0, 81.0, 100.0, 100.0], [39.0, 'Jigglypuff', 'NormalFairy', 270.0, 115.0, 45.0, 20.0, 45.0, 25.0, 20.0], [40.0, 'Wigglytuff', 'NormalFairy', 435.0, 140.0, 70.0, 45.0, 85.0, 50.0, 45.0], [41.0, 'Zubat', 'PoisonFlying', 245.0, 40.0, 45.0, 35.0, 30.0, 40.0, 55.0], [42.0, 'Golbat', 'PoisonFlying', 455.0, 75.0, 80.0, 70.0, 65.0, 75.0, 90.0], [43.0, 'Oddish', 'GrassPoison', 320.0, 45.0, 50.0, 55.0, 75.0, 65.0, 30.0], [44.0, 'Gloom', 'GrassPoison', 395.0, 60.0, 65.0, 70.0, 85.0, 75.0, 40.0], [45.0,  ...

# %%
#pokedex1 = [[ele.strip('"') for i2, ele in enumerate(line.rstrip("\n").split(",")) ] for line in raw_pd]
#print pokedex1

# %%
#pokedex2 = map(float, filter(lambda x: x.isdigit(), [e for inner in pokedex1[1:] for e in inner]))
#print pokedex2

# %%
for inner in pokedex1[:]:
    for e in inner:
        print e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-8815a4bb81e8> in <module>()
# ----> 1 for inner in pokedex1[:]:
#       2     for e in inner:
#       3         print e
#
# NameError: name 'pokedex1' is not defined

# %%
# Example output (first 3 sublists):
#
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %% [markdown]
# <img src="http://imgur.com/gGrau8s.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %%
# Example output (first 3 sublists):
#
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
print pokedex_ls[0]
# Out:
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']

# %%
# Example output:
#
# {'Attack': 30.0,
#  'Defense': 50.0,
#  'HP': 40.0,
#  'Name': 'Voltorb',
#  'SpecialAttack': 55.0,
#  'SpecialDefense': 55.0,
#  'Speed': 100.0,
#  'Total': 330.0,
#  'Type': 'Electric'}

keys = []
for i, stat in enumerate(pokedex_ls[0]):
    keys.append(stat)
    
pokedex2 = pokedex_ls

pokedex = {}
for i, line in enumerate(pokedex2[1:]):
    zip_action = dict(zip(keys,line))
    pokedex[i+1]=zip_action




def poke_search(poke_id):
    pokemon_w_pid = []
    for p in pokedex:
        if pokedex[p]['PokedexNumber'] == poke_id:
            pokemon_w_pid.append(pokedex[p])
    return pokemon_w_pid

poke_search(100.0)
# Out:
# [{'Attack': 30.0,
#   'Defense': 50.0,
#   'HP': 40.0,
#   'Name': 'Voltorb',
#   'PokedexNumber': 100.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed': 100.0,
#   'Total': 330.0,
#   'Type': 'Electric'}]

# %%
pokedex
# Out:
# {1: {'Attack': 49.0,
#   'Defense': 49.0,
#   'HP': 45.0,
#   'Name': 'Bulbasaur',
#   'PokedexNumber': 1.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed': 45.0,
#   'Total': 318.0,
#   'Type': 'GrassPoison'},
#  2: {'Attack': 62.0,
#   'Defense': 63.0,
#   'HP': 60.0,
#   'Name': 'Ivysaur',
#   'PokedexNumber': 2.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed': 60.0,
#   'Total': 405.0,
#   'Type': 'GrassPoison'},
#  3: {'Attack': 82.0,
#   'Defense': 83.0,
#   'HP': 80.0,
#   'Name': 'Venusaur',
#   'PokedexNumber': 3.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 100.0,
#   'Speed': 80.0,
#   'Total': 525.0,
#   'Type': 'GrassPoison'},
#  4: {'Attack': 100.0,
#   'Defense': 123.0,
#   'HP': 80.0,
#   'Name': 'VenusaurMega Venusaur',
#   'PokedexNumber': 3.0,
#   'SpecialAttack': 122.0,
#   'SpecialDefense': 120.0,
#   'Speed': 80.0,
#   'Total': 625.0,
#   'Type': 'GrassPoison'},
#  5: {'Attack': 52.0,
#   'Defense': 43.0,
#   'HP': 39.0,
#   'Name': 'Charmander',
#   'PokedexNumber': 4.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 50.0,
#   'Speed': 65.0,
#   'Total': 309.0,
#   'Type': 'Fire'},
#  6: {'Attack': 64.0,
#   'Defense': 58.0,
#   'HP': 58.0,
#   'Name': 'Charmeleon',
#   'PokedexNumber': 5.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 65.0,
#   'Speed': 80.0,
#   'Total': 405.0,
#   'Type': 'Fire'},
#  7: {'Attack': 84.0,
#   'Defense': 78.0,
#   'HP': 78.0,
#   'Name': 'Charizard',
#   'PokedexNumber': 6.0,
#   'SpecialAttack': 109.0,
#   'SpecialDefense': 85.0,
#   'Speed': 100.0,
#   'Total': 534.0,
#   'Type': 'FireFlying'},
#  8: {'Attack': 130.0,
#   'Defense': 111.0,
#   'HP': 78.0,
#   'Name': 'CharizardMega Charizard X',
#   'PokedexNumber': 6.0,
#   'SpecialAttack': 130.0,
#   'SpecialDefense': 85.0,
#   'Speed': 100.0,
#   'Total': 634.0,
#   'Type': 'FireDragon'},
#  9: {'Attack': 104.0,
#   'Defense': 78.0,
#   'HP': 78.0,
#   'Name': 'CharizardMega Charizard Y',
#   'PokedexNumber': 6.0,
#   'SpecialAttack': 159.0,
#   'SpecialDefense': 115.0,
#   'Speed': 100.0,
#   'Total': 634.0,
#   'Type': 'FireFlying'},
#  10: {'Attack': 48.0,
#   'Defense': 65.0,
#   'HP': 44.0,
#   'Name': 'Squirtle',
#   'PokedexNumber': 7.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 64.0,
#   'Speed': 43.0,
#   'Total': 314.0,
#   'Type': 'Water'},
#  11: {'Attack': 63.0,
#   'Defense': 80.0,
#   'HP': 59.0,
#   'Name': 'Wartortle',
#   'PokedexNumber': 8.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 80.0,
#   'Speed': 58.0,
#   'Total': 405.0,
#   'Type': 'Water'},
#  12: {'Attack': 83.0,
#   'Defense': 100.0,
#   'HP': 79.0,
#   'Name': 'Blastoise',
#   'PokedexNumber': 9.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 105.0,
#   'Speed': 78.0,
#   'Total': 530.0,
#   'Type': 'Water'},
#  13: {'Attack': 103.0,
#   'Defense': 120.0,
#   'HP': 79.0,
#   'Name': 'BlastoiseMega Blastoise',
#   'PokedexNumber': 9.0,
#   'SpecialAttack': 135.0,
#   'SpecialDefense': 115.0,
#   'Speed': 78.0,
#   'Total': 630.0,
#   'Type': 'Water'},
#  14: {'Attack': 30.0,
#   'Defense': 35.0,
#   'HP': 45.0,
#   'Name': 'Caterpie',
#   'PokedexNumber': 10.0,
#   'SpecialAttack': 20.0,
#   'SpecialDefense': 20.0,
#   'Speed': 45.0,
#   'Total': 195.0,
#   'Type': 'Bug'},
#  15: {'Attack': 20.0,
#   'Defense': 55.0,
#   'HP': 50.0,
#   'Name': 'Metapod',
#   'PokedexNumber': 11.0,
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 25.0,
#   'Speed': 30.0,
#   'Total': 205.0,
#   'Type': 'Bug'},
#  16: {'Attack': 45.0,
#   'Defense': 50.0,
#   'HP': 60.0,
#   'Name': 'Butterfree',
#   'PokedexNumber': 12.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 80.0,
#   'Speed': 70.0,
#   'Total': 395.0,
#   'Type': 'BugFlying'},
#  17: {'Attack': 35.0,
#   'Defense': 30.0,
#   'HP': 40.0,
#   'Name': 'Weedle',
#   'PokedexNumber': 13.0,
#   'SpecialAttack': 20.0,
#   'SpecialDefense': 20.0,
#   'Speed': 50.0,
#   'Total': 195.0,
#   'Type': 'BugPoison'},
#  18: {'Attack': 25.0,
#   'Defense': 50.0,
#   'HP': 45.0,
#   'Name': 'Kakuna',
#   'PokedexNumber': 14.0,
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 25.0,
#   'Speed': 35.0,
#   'Total': 205.0,
#   'Type': 'BugPoison'},
#  19: {'Attack': 90.0,
#   'Defense': 40.0,
#   'HP': 65.0,
#   'Name': 'Beedrill',
#   'PokedexNumber': 15.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 80.0,
#   'Speed': 75.0,
#   'Total': 395.0,
#   'Type': 'BugPoison'},
#  20: {'Attack': 150.0,
#   'Defense': 40.0,
#   'HP': 65.0,
#   'Name': 'BeedrillMega Beedrill',
#   'PokedexNumber': 15.0,
#   'SpecialAttack': 15.0,
#   'SpecialDefense': 80.0,
#   'Speed': 145.0,
#   'Total': 495.0,
#   'Type': 'BugPoison'},
#  21: {'Attack': 45.0,
#   'Defense': 40.0,
#   'HP': 40.0,
#   'Name': 'Pidgey',
#   'PokedexNumber': 16.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed': 56.0,
#   'Total': 251.0,
#   'Type': 'NormalFlying'},
#  22: {'Attack': 60.0,
#   'Defense': 55.0,
#   'HP': 63.0,
#   'Name': 'Pidgeotto',
#   'PokedexNumber': 17.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed': 71.0,
#   'Total': 349.0,
#   'Type': 'NormalFlying'},
#  23: {'Attack': 80.0,
#   'Defense': 75.0,
#   'HP': 83.0,
#   'Name': 'Pidgeot',
#   'PokedexNumber': 18.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 70.0,
#   'Speed': 101.0,
#   'Total': 479.0,
#   'Type': 'NormalFlying'},
#  24: {'Attack': 80.0,
#   'Defense': 80.0,
#   'HP': 83.0,
#   'Name': 'PidgeotMega Pidgeot',
#   'PokedexNumber': 18.0,
#   'SpecialAttack': 135.0,
#   'SpecialDefense': 80.0,
#   'Speed': 121.0,
#   'Total': 579.0,
#   'Type': 'NormalFlying'},
#  25: {'Attack': 56.0,
#   'Defense': 35.0,
#   'HP': 30.0,
#   'Name': 'Rattata',
#   'PokedexNumber': 19.0,
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 35.0,
#   'Speed': 72.0,
#   'Total': 253.0,
#   'Type': 'Normal'},
#  26: {'Attack': 81.0,
#   'Defense': 60.0,
#   'HP': 55.0,
#   'Name': 'Raticate',
#   'PokedexNumber': 20.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 70.0,
#   'Speed': 97.0,
#   'Total': 413.0,
#   'Type': 'Normal'},
#  27: {'Attack': 60.0,
#   'Defense': 30.0,
#   'HP': 40.0,
#   'Name': 'Spearow',
#   'PokedexNumber': 21.0,
#   'SpecialAttack': 31.0,
#   'SpecialDefense': 31.0,
#   'Speed': 70.0,
#   'Total': 262.0,
#   'Type': 'NormalFlying'},
#  28: {'Attack': 90.0,
#   'Defense': 65.0,
#   'HP': 65.0,
#   'Name': 'Fearow',
#   'PokedexNumber': 22.0,
#   'SpecialAttack': 61.0,
#   'SpecialDefense': 61.0,
#   'Speed': 100.0,
#   'Total': 442.0,
#   'Type': 'NormalFlying'},
#  29: {'Attack': 60.0,
#   'Defense': 44.0,
#   'HP': 35.0,
#   'Name': 'Ekans',
#   'PokedexNumber': 23.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 54.0,
#   'Speed': 55.0,
#   'Total': 288.0,
#   'Type': 'Poison'},
#  30: {'Attack': 85.0,
#   'Defense': 69.0,
#   'HP': 60.0,
#   'Name': 'Arbok',
#   'PokedexNumber': 24.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 79.0,
#   'Speed': 80.0,
#   'Total': 438.0,
#   'Type': 'Poison'},
#  31: {'Attack': 55.0,
#   'Defense': 40.0,
#   'HP': 35.0,
#   'Name': 'Pikachu',
#   'PokedexNumber': 25.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed': 90.0,
#   'Total': 320.0,
#   'Type': 'Electric'},
#  32: {'Attack': 90.0,
#   'Defense': 55.0,
#   'HP': 60.0,
#   'Name': 'Raichu',
#   'PokedexNumber': 26.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 80.0,
#   'Speed': 110.0,
#   'Total': 485.0,
#   'Type': 'Electric'},
#  33: {'Attack': 75.0,
#   'Defense': 85.0,
#   'HP': 50.0,
#   'Name': 'Sandshrew',
#   'PokedexNumber': 27.0,
#   'SpecialAttack': 20.0,
#   'SpecialDefense': 30.0,
#   'Speed': 40.0,
#   'Total': 300.0,
#   'Type': 'Ground'},
#  34: {'Attack': 100.0,
#   'Defense': 110.0,
#   'HP': 75.0,
#   'Name': 'Sandslash',
#   'PokedexNumber': 28.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 55.0,
#   'Speed': 65.0,
#   'Total': 450.0,
#   'Type': 'Ground'},
#  35: {'Attack': 47.0,
#   'Defense': 52.0,
#   'HP': 55.0,
#   'Name': 'Nidoran\xe2\x99\x80',
#   'PokedexNumber': 29.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed': 41.0,
#   'Total': 275.0,
#   'Type': 'Poison'},
#  36: {'Attack': 62.0,
#   'Defense': 67.0,
#   'HP': 70.0,
#   'Name': 'Nidorina',
#   'PokedexNumber': 30.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed': 56.0,
#   'Total': 365.0,
#   'Type': 'Poison'},
#  37: {'Attack': 92.0,
#   'Defense': 87.0,
#   'HP': 90.0,
#   'Name': 'Nidoqueen',
#   'PokedexNumber': 31.0,
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 85.0,
#   'Speed': 76.0,
#   'Total': 505.0,
#   'Type': 'PoisonGround'},
#  38: {'Attack': 57.0,
#   'Defense': 40.0,
#   'HP': 46.0,
#   'Name': 'Nidoran\xe2\x99\x82',
#   'PokedexNumber': 32.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed': 50.0,
#   'Total': 273.0,
#   'Type': 'Poison'},
#  39: {'Attack': 72.0,
#   'Defense': 57.0,
#   'HP': 61.0,
#   'Name': 'Nidorino',
#   'PokedexNumber': 33.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed': 65.0,
#   'Total': 365.0,
#   'Type': 'Poison'},
#  40: {'Attack': 102.0,
#   'Defense': 77.0,
#   'HP': 81.0,
#   'Name': 'Nidoking',
#   'PokedexNumber': 34.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 75.0,
#   'Speed': 85.0,
#   'Total': 505.0,
#   'Type': 'PoisonGround'},
#  41: {'Attack': 45.0,
#   'Defense': 48.0,
#   'HP': 70.0,
#   'Name': 'Clefairy',
#   'PokedexNumber': 35.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 65.0,
#   'Speed': 35.0,
#   'Total': 323.0,
#   'Type': 'Fairy'},
#  42: {'Attack': 70.0,
#   'Defense': 73.0,
#   'HP': 95.0,
#   'Name': 'Clefable',
#   'PokedexNumber': 36.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 90.0,
#   'Speed': 60.0,
#   'Total': 483.0,
#   'Type': 'Fairy'},
#  43: {'Attack': 41.0,
#   'Defense': 40.0,
#   'HP': 38.0,
#   'Name': 'Vulpix',
#   'PokedexNumber': 37.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 65.0,
#   'Speed': 65.0,
#   'Total': 299.0,
#   'Type': 'Fire'},
#  44: {'Attack': 76.0,
#   'Defense': 75.0,
#   'HP': 73.0,
#   'Name': 'Ninetales',
#   'PokedexNumber': 38.0,
#   'SpecialAttack': 81.0,
#   'SpecialDefense': 100.0,
#   'Speed': 100.0,
#   'Total': 505.0,
#   'Type': 'Fire'},
#  45: {'Attack': 45.0,
#   'Defense': 20.0,
#   'HP': 115.0,
#   'Name': 'Jigglypuff',
#   'PokedexNumber': 39.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 25.0,
#   'Speed': 20.0,
#   'Total': 270.0,
#   'Type': 'NormalFairy'},
#  46: {'Attack': 70.0,
#   'Defense': 45.0,
#   'HP': 140.0,
#   'Name': 'Wigglytuff',
#   'PokedexNumber': 40.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 50.0,
#   'Speed': 45.0,
#   'Total': 435.0,
#   'Type': 'NormalFairy'},
#  47: {'Attack': 45.0,
#   'Defense': 35.0,
#   'HP': 40.0,
#   'Name': 'Zubat',
#   'PokedexNumber': 41.0,
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 40.0,
#   'Speed': 55.0,
#   'Total': 245.0,
#   'Type': 'PoisonFlying'},
#  48: {'Attack': 80.0,
#   'Defense': 70.0,
#   'HP': 75.0,
#   'Name': 'Golbat',
#   'PokedexNumber': 42.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 75.0,
#   'Speed': 90.0,
#   'Total': 455.0,
#   'Type': 'PoisonFlying'},
#  49: {'Attack': 50.0,
#   'Defense': 55.0,
#   'HP': 45.0,
#   'Name': 'Oddish',
#   'PokedexNumber': 43.0,
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 65.0,
#   'Speed': 30.0,
#   'Total': 320.0,
#   'Type': 'GrassPoison'},
#  50: {'Attack': 65.0,
#   'Defense': 70.0,
#   'HP': 60.0,
#   'Name': 'Gloom',
#   'PokedexNumber': 44.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 75.0,
#   'Speed': 40.0,
#   'Total': 395.0,
#   'Type': 'GrassPoison'},
#  51: {'Attack': 80.0,
#   'Defense': 85.0,
#   'HP': 75.0,
#   'Name': 'Vileplume',
#   'PokedexNumber': 45.0,
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 90.0,
#   'Speed': 50.0,
#   'Total': 490.0,
#   'Type': 'GrassPoison'},
#  52: {'Attack': 70.0,
#   'Defense': 55.0,
#   'HP': 35.0,
#   'Name': 'Paras',
#   'PokedexNumber': 46.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 55.0,
#   'Speed': 25.0,
#   'Total': 285.0,
#   'Type': 'BugGrass'},
#  53: {'Attack': 95.0,
#   'Defense': 80.0,
#   'HP': 60.0,
#   'Name': 'Parasect',
#   'PokedexNumber': 47.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 80.0,
#   'Speed': 30.0,
#   'Total': 405.0,
#   'Type': 'BugGrass'},
#  54: {'Attack': 55.0,
#   'Defense': 50.0,
#   'HP': 60.0,
#   'Name': 'Venonat',
#   'PokedexNumber': 48.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 55.0,
#   'Speed': 45.0,
#   'Total': 305.0,
#   'Type': 'BugPoison'},
#  55: {'Attack': 65.0,
#   'Defense': 60.0,
#   'HP': 70.0,
#   'Name': 'Venomoth',
#   'PokedexNumber': 49.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 75.0,
#   'Speed': 90.0,
#   'Total': 450.0,
#   'Type': 'BugPoison'},
#  56: {'Attack': 55.0,
#   'Defense': 25.0,
#   'HP': 10.0,
#   'Name': 'Diglett',
#   'PokedexNumber': 50.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 45.0,
#   'Speed': 95.0,
#   'Total': 265.0,
#   'Type': 'Ground'},
#  57: {'Attack': 80.0,
#   'Defense': 50.0,
#   'HP': 35.0,
#   'Name': 'Dugtrio',
#   'PokedexNumber': 51.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 70.0,
#   'Speed': 120.0,
#   'Total': 405.0,
#   'Type': 'Ground'},
#  58: {'Attack': 45.0,
#   'Defense': 35.0,
#   'HP': 40.0,
#   'Name': 'Meowth',
#   'PokedexNumber': 52.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed': 90.0,
#   'Total': 290.0,
#   'Type': 'Normal'},
#  59: {'Attack': 70.0,
#   'Defense': 60.0,
#   'HP': 65.0,
#   'Name': 'Persian',
#   'PokedexNumber': 53.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed': 115.0,
#   'Total': 440.0,
#   'Type': 'Normal'},
#  60: {'Attack': 52.0,
#   'Defense': 48.0,
#   'HP': 50.0,
#   'Name': 'Psyduck',
#   'PokedexNumber': 54.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 50.0,
#   'Speed': 55.0,
#   'Total': 320.0,
#   'Type': 'Water'},
#  61: {'Attack': 82.0,
#   'Defense': 78.0,
#   'HP': 80.0,
#   'Name': 'Golduck',
#   'PokedexNumber': 55.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 80.0,
#   'Speed': 85.0,
#   'Total': 500.0,
#   'Type': 'Water'},
#  62: {'Attack': 80.0,
#   'Defense': 35.0,
#   'HP': 40.0,
#   'Name': 'Mankey',
#   'PokedexNumber': 56.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 45.0,
#   'Speed': 70.0,
#   'Total': 305.0,
#   'Type': 'Fighting'},
#  63: {'Attack': 105.0,
#   'Defense': 60.0,
#   'HP': 65.0,
#   'Name': 'Primeape',
#   'PokedexNumber': 57.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 70.0,
#   'Speed': 95.0,
#   'Total': 455.0,
#   'Type': 'Fighting'},
#  64: {'Attack': 70.0,
#   'Defense': 45.0,
#   'HP': 55.0,
#   'Name': 'Growlithe',
#   'PokedexNumber': 58.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 50.0,
#   'Speed': 60.0,
#   'Total': 350.0,
#   'Type': 'Fire'},
#  65: {'Attack': 110.0,
#   'Defense': 80.0,
#   'HP': 90.0,
#   'Name': 'Arcanine',
#   'PokedexNumber': 59.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 80.0,
#   'Speed': 95.0,
#   'Total': 555.0,
#   'Type': 'Fire'},
#  66: {'Attack': 50.0,
#   'Defense': 40.0,
#   'HP': 40.0,
#   'Name': 'Poliwag',
#   'PokedexNumber': 60.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed': 90.0,
#   'Total': 300.0,
#   'Type': 'Water'},
#  67: {'Attack': 65.0,
#   'Defense': 65.0,
#   'HP': 65.0,
#   'Name': 'Poliwhirl',
#   'PokedexNumber': 61.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed': 90.0,
#   'Total': 385.0,
#   'Type': 'Water'},
#  68: {'Attack': 95.0,
#   'Defense': 95.0,
#   'HP': 90.0,
#   'Name': 'Poliwrath',
#   'PokedexNumber': 62.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 90.0,
#   'Speed': 70.0,
#   'Total': 510.0,
#   'Type': 'WaterFighting'},
#  69: {'Attack': 20.0,
#   'Defense': 15.0,
#   'HP': 25.0,
#   'Name': 'Abra',
#   'PokedexNumber': 63.0,
#   'SpecialAttack': 105.0,
#   'SpecialDefense': 55.0,
#   'Speed': 90.0,
#   'Total': 310.0,
#   'Type': 'Psychic'},
#  70: {'Attack': 35.0,
#   'Defense': 30.0,
#   'HP': 40.0,
#   'Name': 'Kadabra',
#   'PokedexNumber': 64.0,
#   'SpecialAttack': 120.0,
#   'SpecialDefense': 70.0,
#   'Speed': 105.0,
#   'Total': 400.0,
#   'Type': 'Psychic'},
#  71: {'Attack': 50.0,
#   'Defense': 45.0,
#   'HP': 55.0,
#   'Name': 'Alakazam',
#   'PokedexNumber': 65.0,
#   'SpecialAttack': 135.0,
#   'SpecialDefense': 95.0,
#   'Speed': 120.0,
#   'Total': 500.0,
#   'Type': 'Psychic'},
#  72: {'Attack': 50.0,
#   'Defense': 65.0,
#   'HP': 55.0,
#   'Name': 'AlakazamMega Alakazam',
#   'PokedexNumber': 65.0,
#   'SpecialAttack': 175.0,
#   'SpecialDefense': 95.0,
#   'Speed': 150.0,
#   'Total': 590.0,
#   'Type': 'Psychic'},
#  73: {'Attack': 80.0,
#   'Defense': 50.0,
#   'HP': 70.0,
#   'Name': 'Machop',
#   'PokedexNumber': 66.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed': 35.0,
#   'Total': 305.0,
#   'Type': 'Fighting'},
#  74: {'Attack': 100.0,
#   'Defense': 70.0,
#   'HP': 80.0,
#   'Name': 'Machoke',
#   'PokedexNumber': 67.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 60.0,
#   'Speed': 45.0,
#   'Total': 405.0,
#   'Type': 'Fighting'},
#  75: {'Attack': 130.0,
#   'Defense': 80.0,
#   'HP': 90.0,
#   'Name': 'Machamp',
#   'PokedexNumber': 68.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 85.0,
#   'Speed': 55.0,
#   'Total': 505.0,
#   'Type': 'Fighting'},
#  76: {'Attack': 75.0,
#   'Defense': 35.0,
#   'HP': 50.0,
#   'Name': 'Bellsprout',
#   'PokedexNumber': 69.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 30.0,
#   'Speed': 40.0,
#   'Total': 300.0,
#   'Type': 'GrassPoison'},
#  77: {'Attack': 90.0,
#   'Defense': 50.0,
#   'HP': 65.0,
#   'Name': 'Weepinbell',
#   'PokedexNumber': 70.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 45.0,
#   'Speed': 55.0,
#   'Total': 390.0,
#   'Type': 'GrassPoison'},
#  78: {'Attack': 105.0,
#   'Defense': 65.0,
#   'HP': 80.0,
#   'Name': 'Victreebel',
#   'PokedexNumber': 71.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 70.0,
#   'Speed': 70.0,
#   'Total': 490.0,
#   'Type': 'GrassPoison'},
#  79: {'Attack': 40.0,
#   'Defense': 35.0,
#   'HP': 40.0,
#   'Name': 'Tentacool',
#   'PokedexNumber': 72.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 100.0,
#   'Speed': 70.0,
#   'Total': 335.0,
#   'Type': 'WaterPoison'},
#  80: {'Attack': 70.0,
#   'Defense': 65.0,
#   'HP': 80.0,
#   'Name': 'Tentacruel',
#   'PokedexNumber': 73.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 120.0,
#   'Speed': 100.0,
#   'Total': 515.0,
#   'Type': 'WaterPoison'},
#  81: {'Attack': 80.0,
#   'Defense': 100.0,
#   'HP': 40.0,
#   'Name': 'Geodude',
#   'PokedexNumber': 74.0,
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 30.0,
#   'Speed': 20.0,
#   'Total': 300.0,
#   'Type': 'RockGround'},
#  82: {'Attack': 95.0,
#   'Defense': 115.0,
#   'HP': 55.0,
#   'Name': 'Graveler',
#   'PokedexNumber': 75.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 45.0,
#   'Speed': 35.0,
#   'Total': 390.0,
#   'Type': 'RockGround'},
#  83: {'Attack': 120.0,
#   'Defense': 130.0,
#   'HP': 80.0,
#   'Name': 'Golem',
#   'PokedexNumber': 76.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 65.0,
#   'Speed': 45.0,
#   'Total': 495.0,
#   'Type': 'RockGround'},
#  84: {'Attack': 85.0,
#   'Defense': 55.0,
#   'HP': 50.0,
#   'Name': 'Ponyta',
#   'PokedexNumber': 77.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed': 90.0,
#   'Total': 410.0,
#   'Type': 'Fire'},
#  85: {'Attack': 100.0,
#   'Defense': 70.0,
#   'HP': 65.0,
#   'Name': 'Rapidash',
#   'PokedexNumber': 78.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed': 105.0,
#   'Total': 500.0,
#   'Type': 'Fire'},
#  86: {'Attack': 65.0,
#   'Defense': 65.0,
#   'HP': 90.0,
#   'Name': 'Slowpoke',
#   'PokedexNumber': 79.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed': 15.0,
#   'Total': 315.0,
#   'Type': 'WaterPsychic'},
#  87: {'Attack': 75.0,
#   'Defense': 110.0,
#   'HP': 95.0,
#   'Name': 'Slowbro',
#   'PokedexNumber': 80.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 80.0,
#   'Speed': 30.0,
#   'Total': 490.0,
#   'Type': 'WaterPsychic'},
#  88: {'Attack': 75.0,
#   'Defense': 180.0,
#   'HP': 95.0,
#   'Name': 'SlowbroMega Slowbro',
#   'PokedexNumber': 80.0,
#   'SpecialAttack': 130.0,
#   'SpecialDefense': 80.0,
#   'Speed': 30.0,
#   'Total': 590.0,
#   'Type': 'WaterPsychic'},
#  89: {'Attack': 35.0,
#   'Defense': 70.0,
#   'HP': 25.0,
#   'Name': 'Magnemite',
#   'PokedexNumber': 81.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 55.0,
#   'Speed': 45.0,
#   'Total': 325.0,
#   'Type': 'ElectricSteel'},
#  90: {'Attack': 60.0,
#   'Defense': 95.0,
#   'HP': 50.0,
#   'Name': 'Magneton',
#   'PokedexNumber': 82.0,
#   'SpecialAttack': 120.0,
#   'SpecialDefense': 70.0,
#   'Speed': 70.0,
#   'Total': 465.0,
#   'Type': 'ElectricSteel'},
#  91: {'Attack': 65.0,
#   'Defense': 55.0,
#   'HP': 52.0,
#   'Name': "Farfetch'd",
#   'PokedexNumber': 83.0,
#   'SpecialAttack': 58.0,
#   'SpecialDefense': 62.0,
#   'Speed': 60.0,
#   'Total': 352.0,
#   'Type': 'NormalFlying'},
#  92: {'Attack': 85.0,
#   'Defense': 45.0,
#   'HP': 35.0,
#   'Name': 'Doduo',
#   'PokedexNumber': 84.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed': 75.0,
#   'Total': 310.0,
#   'Type': 'NormalFlying'},
#  93: {'Attack': 110.0,
#   'Defense': 70.0,
#   'HP': 60.0,
#   'Name': 'Dodrio',
#   'PokedexNumber': 85.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed': 100.0,
#   'Total': 460.0,
#   'Type': 'NormalFlying'},
#  94: {'Attack': 45.0,
#   'Defense': 55.0,
#   'HP': 65.0,
#   'Name': 'Seel',
#   'PokedexNumber': 86.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 70.0,
#   'Speed': 45.0,
#   'Total': 325.0,
#   'Type': 'Water'},
#  95: {'Attack': 70.0,
#   'Defense': 80.0,
#   'HP': 90.0,
#   'Name': 'Dewgong',
#   'PokedexNumber': 87.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 95.0,
#   'Speed': 70.0,
#   'Total': 475.0,
#   'Type': 'WaterIce'},
#  96: {'Attack': 80.0,
#   'Defense': 50.0,
#   'HP': 80.0,
#   'Name': 'Grimer',
#   'PokedexNumber': 88.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 50.0,
#   'Speed': 25.0,
#   'Total': 325.0,
#   'Type': 'Poison'},
#  97: {'Attack': 105.0,
#   'Defense': 75.0,
#   'HP': 105.0,
#   'Name': 'Muk',
#   'PokedexNumber': 89.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 100.0,
#   'Speed': 50.0,
#   'Total': 500.0,
#   'Type': 'Poison'},
#  98: {'Attack': 65.0,
#   'Defense': 100.0,
#   'HP': 30.0,
#   'Name': 'Shellder',
#   'PokedexNumber': 90.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 25.0,
#   'Speed': 40.0,
#   'Total': 305.0,
#   'Type': 'Water'},
#  99: {'Attack': 95.0,
#   'Defense': 180.0,
#   'HP': 50.0,
#   'Name': 'Cloyster',
#   'PokedexNumber': 91.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 45.0,
#   'Speed': 70.0,
#   'Total': 525.0,
#   'Type': 'WaterIce'},
#  100: {'Attack': 35.0,
#   'Defense': 30.0,
#   'HP': 30.0,
#   'Name': 'Gastly',
#   'PokedexNumber': 92.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 35.0,
#   'Speed': 80.0,
#   'Total': 310.0,
#   'Type': 'GhostPoison'},
#  101: {'Attack': 50.0,
#   'Defense': 45.0,
#   'HP': 45.0,
#   'Name': 'Haunter',
#   'PokedexNumber': 93.0,
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 55.0,
#   'Speed': 95.0,
#   'Total': 405.0,
#   'Type': 'GhostPoison'},
#  102: {'Attack': 65.0,
#   'Defense': 60.0,
#   'HP': 60.0,
#   'Name': 'Gengar',
#   'PokedexNumber': 94.0,
#   'SpecialAttack': 130.0,
#   'SpecialDefense': 75.0,
#   'Speed': 110.0,
#   'Total': 500.0,
#   'Type': 'GhostPoison'},
#  103: {'Attack': 65.0,
#   'Defense': 80.0,
#   'HP': 60.0,
#   'Name': 'GengarMega Gengar',
#   'PokedexNumber': 94.0,
#   'SpecialAttack': 170.0,
#   'SpecialDefense': 95.0,
#   'Speed': 130.0,
#   'Total': 600.0,
#   'Type': 'GhostPoison'},
#  104: {'Attack': 45.0,
#   'Defense': 160.0,
#   'HP': 35.0,
#   'Name': 'Onix',
#   'PokedexNumber': 95.0,
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 45.0,
#   'Speed': 70.0,
#   'Total': 385.0,
#   'Type': 'RockGround'},
#  105: {'Attack': 48.0,
#   'Defense': 45.0,
#   'HP': 60.0,
#   'Name': 'Drowzee',
#   'PokedexNumber': 96.0,
#   'SpecialAttack': 43.0,
#   'SpecialDefense': 90.0,
#   'Speed': 42.0,
#   'Total': 328.0,
#   'Type': 'Psychic'},
#  106: {'Attack': 73.0,
#   'Defense': 70.0,
#   'HP': 85.0,
#   'Name': 'Hypno',
#   'PokedexNumber': 97.0,
#   'SpecialAttack': 73.0,
#   'SpecialDefense': 115.0,
#   'Speed': 67.0,
#   'Total': 483.0,
#   'Type': 'Psychic'},
#  107: {'Attack': 105.0,
#   'Defense': 90.0,
#   'HP': 30.0,
#   'Name': 'Krabby',
#   'PokedexNumber': 98.0,
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 25.0,
#   'Speed': 50.0,
#   'Total': 325.0,
#   'Type': 'Water'},
#  108: {'Attack': 130.0,
#   'Defense': 115.0,
#   'HP': 55.0,
#   'Name': 'Kingler',
#   'PokedexNumber': 99.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed': 75.0,
#   'Total': 475.0,
#   'Type': 'Water'},
#  109: {'Attack': 30.0,
#   'Defense': 50.0,
#   'HP': 40.0,
#   'Name': 'Voltorb',
#   'PokedexNumber': 100.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed': 100.0,
#   'Total': 330.0,
#   'Type': 'Electric'},
#  110: {'Attack': 50.0,
#   'Defense': 70.0,
#   'HP': 60.0,
#   'Name': 'Electrode',
#   'PokedexNumber': 101.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed': 140.0,
#   'Total': 480.0,
#   'Type': 'Electric'},
#  111: {'Attack': 40.0,
#   'Defense': 80.0,
#   'HP': 60.0,
#   'Name': 'Exeggcute',
#   'PokedexNumber': 102.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 45.0,
#   'Speed': 40.0,
#   'Total': 325.0,
#   'Type': 'GrassPsychic'},
#  112: {'Attack': 95.0,
#   'Defense': 85.0,
#   'HP': 95.0,
#   'Name': 'Exeggutor',
#   'PokedexNumber': 103.0,
#   'SpecialAttack': 125.0,
#   'SpecialDefense': 65.0,
#   'Speed': 55.0,
#   'Total': 520.0,
#   'Type': 'GrassPsychic'},
#  113: {'Attack': 50.0,
#   'Defense': 95.0,
#   'HP': 50.0,
#   'Name': 'Cubone',
#   'PokedexNumber': 104.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 50.0,
#   'Speed': 35.0,
#   'Total': 320.0,
#   'Type': 'Ground'},
#  114: {'Attack': 80.0,
#   'Defense': 110.0,
#   'HP': 60.0,
#   'Name': 'Marowak',
#   'PokedexNumber': 105.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 80.0,
#   'Speed': 45.0,
#   'Total': 425.0,
#   'Type': 'Ground'},
#  115: {'Attack': 120.0,
#   'Defense': 53.0,
#   'HP': 50.0,
#   'Name': 'Hitmonlee',
#   'PokedexNumber': 106.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 110.0,
#   'Speed': 87.0,
#   'Total': 455.0,
#   'Type': 'Fighting'},
#  116: {'Attack': 105.0,
#   'Defense': 79.0,
#   'HP': 50.0,
#   'Name': 'Hitmonchan',
#   'PokedexNumber': 107.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 110.0,
#   'Speed': 76.0,
#   'Total': 455.0,
#   'Type': 'Fighting'},
#  117: {'Attack': 55.0,
#   'Defense': 75.0,
#   'HP': 90.0,
#   'Name': 'Lickitung',
#   'PokedexNumber': 108.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 75.0,
#   'Speed': 30.0,
#   'Total': 385.0,
#   'Type': 'Normal'},
#  118: {'Attack': 65.0,
#   'Defense': 95.0,
#   'HP': 40.0,
#   'Name': 'Koffing',
#   'PokedexNumber': 109.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 45.0,
#   'Speed': 35.0,
#   'Total': 340.0,
#   'Type': 'Poison'},
#  119: {'Attack': 90.0,
#   'Defense': 120.0,
#   'HP': 65.0,
#   'Name': 'Weezing',
#   'PokedexNumber': 110.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 70.0,
#   'Speed': 60.0,
#   'Total': 490.0,
#   'Type': 'Poison'},
#  120: {'Attack': 85.0,
#   'Defense': 95.0,
#   'HP': 80.0,
#   'Name': 'Rhyhorn',
#   'PokedexNumber': 111.0,
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 30.0,
#   'Speed': 25.0,
#   'Total': 345.0,
#   'Type': 'GroundRock'},
#  121: {'Attack': 130.0,
#   'Defense': 120.0,
#   'HP': 105.0,
#   'Name': 'Rhydon',
#   'PokedexNumber': 112.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 45.0,
#   'Speed': 40.0,
#   'Total': 485.0,
#   'Type': 'GroundRock'},
#  122: {'Attack': 5.0,
#   'Defense': 5.0,
#   'HP': 250.0,
#   'Name': 'Chansey',
#   'PokedexNumber': 113.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 105.0,
#   'Speed': 50.0,
#   'Total': 450.0,
#   'Type': 'Normal'},
#  123: {'Attack': 55.0,
#   'Defense': 115.0,
#   'HP': 65.0,
#   'Name': 'Tangela',
#   'PokedexNumber': 114.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 40.0,
#   'Speed': 60.0,
#   'Total': 435.0,
#   'Type': 'Grass'},
#  124: {'Attack': 95.0,
#   'Defense': 80.0,
#   'HP': 105.0,
#   'Name': 'Kangaskhan',
#   'PokedexNumber': 115.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 80.0,
#   'Speed': 90.0,
#   'Total': 490.0,
#   'Type': 'Normal'},
#  125: {'Attack': 125.0,
#   'Defense': 100.0,
#   'HP': 105.0,
#   'Name': 'KangaskhanMega Kangaskhan',
#   'PokedexNumber': 115.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 100.0,
#   'Speed': 100.0,
#   'Total': 590.0,
#   'Type': 'Normal'},
#  126: {'Attack': 40.0,
#   'Defense': 70.0,
#   'HP': 30.0,
#   'Name': 'Horsea',
#   'PokedexNumber': 116.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 25.0,
#   'Speed': 60.0,
#   'Total': 295.0,
#   'Type': 'Water'},
#  127: {'Attack': 65.0,
#   'Defense': 95.0,
#   'HP': 55.0,
#   'Name': 'Seadra',
#   'PokedexNumber': 117.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 45.0,
#   'Speed': 85.0,
#   'Total': 440.0,
#   'Type': 'Water'},
#  128: {'Attack': 67.0,
#   'Defense': 60.0,
#   'HP': 45.0,
#   'Name': 'Goldeen',
#   'PokedexNumber': 118.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 50.0,
#   'Speed': 63.0,
#   'Total': 320.0,
#   'Type': 'Water'},
#  129: {'Attack': 92.0,
#   'Defense': 65.0,
#   'HP': 80.0,
#   'Name': 'Seaking',
#   'PokedexNumber': 119.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 80.0,
#   'Speed': 68.0,
#   'Total': 450.0,
#   'Type': 'Water'},
#  130: {'Attack': 45.0,
#   'Defense': 55.0,
#   'HP': 30.0,
#   'Name': 'Staryu',
#   'PokedexNumber': 120.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 55.0,
#   'Speed': 85.0,
#   'Total': 340.0,
#   'Type': 'Water'},
#  131: {'Attack': 75.0,
#   'Defense': 85.0,
#   'HP': 60.0,
#   'Name': 'Starmie',
#   'PokedexNumber': 121.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 85.0,
#   'Speed': 115.0,
#   'Total': 520.0,
#   'Type': 'WaterPsychic'},
#  132: {'Attack': 45.0,
#   'Defense': 65.0,
#   'HP': 40.0,
#   'Name': 'Mr. Mime',
#   'PokedexNumber': 122.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 120.0,
#   'Speed': 90.0,
#   'Total': 460.0,
#   'Type': 'PsychicFairy'},
#  133: {'Attack': 110.0,
#   'Defense': 80.0,
#   'HP': 70.0,
#   'Name': 'Scyther',
#   'PokedexNumber': 123.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 80.0,
#   'Speed': 105.0,
#   'Total': 500.0,
#   'Type': 'BugFlying'},
#  134: {'Attack': 50.0,
#   'Defense': 35.0,
#   'HP': 65.0,
#   'Name': 'Jynx',
#   'PokedexNumber': 124.0,
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 95.0,
#   'Speed': 95.0,
#   'Total': 455.0,
#   'Type': 'IcePsychic'},
#  135: {'Attack': 83.0,
#   'Defense': 57.0,
#   'HP': 65.0,
#   'Name': 'Electabuzz',
#   'PokedexNumber': 125.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 85.0,
#   'Speed': 105.0,
#   'Total': 490.0,
#   'Type': 'Electric'},
#  136: {'Attack': 95.0,
#   'Defense': 57.0,
#   'HP': 65.0,
#   'Name': 'Magmar',
#   'PokedexNumber': 126.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 85.0,
#   'Speed': 93.0,
#   'Total': 495.0,
#   'Type': 'Fire'},
#  137: {'Attack': 125.0,
#   'Defense': 100.0,
#   'HP': 65.0,
#   'Name': 'Pinsir',
#   'PokedexNumber': 127.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 70.0,
#   'Speed': 85.0,
#   'Total': 500.0,
#   'Type': 'Bug'},
#  138: {'Attack': 155.0,
#   'Defense': 120.0,
#   'HP': 65.0,
#   'Name': 'PinsirMega Pinsir',
#   'PokedexNumber': 127.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 90.0,
#   'Speed': 105.0,
#   'Total': 600.0,
#   'Type': 'BugFlying'},
#  139: {'Attack': 100.0,
#   'Defense': 95.0,
#   'HP': 75.0,
#   'Name': 'Tauros',
#   'PokedexNumber': 128.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 70.0,
#   'Speed': 110.0,
#   'Total': 490.0,
#   'Type': 'Normal'},
#  140: {'Attack': 10.0,
#   'Defense': 55.0,
#   'HP': 20.0,
#   'Name': 'Magikarp',
#   'PokedexNumber': 129.0,
#   'SpecialAttack': 15.0,
#   'SpecialDefense': 20.0,
#   'Speed': 80.0,
#   'Total': 200.0,
#   'Type': 'Water'},
#  141: {'Attack': 125.0,
#   'Defense': 79.0,
#   'HP': 95.0,
#   'Name': 'Gyarados',
#   'PokedexNumber': 130.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 100.0,
#   'Speed': 81.0,
#   'Total': 540.0,
#   'Type': 'WaterFlying'},
#  142: {'Attack': 155.0,
#   'Defense': 109.0,
#   'HP': 95.0,
#   'Name': 'GyaradosMega Gyarados',
#   'PokedexNumber': 130.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 130.0,
#   'Speed': 81.0,
#   'Total': 640.0,
#   'Type': 'WaterDark'},
#  143: {'Attack': 85.0,
#   'Defense': 80.0,
#   'HP': 130.0,
#   'Name': 'Lapras',
#   'PokedexNumber': 131.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 95.0,
#   'Speed': 60.0,
#   'Total': 535.0,
#   'Type': 'WaterIce'},
#  144: {'Attack': 48.0,
#   'Defense': 48.0,
#   'HP': 48.0,
#   'Name': 'Ditto',
#   'PokedexNumber': 132.0,
#   'SpecialAttack': 48.0,
#   'SpecialDefense': 48.0,
#   'Speed': 48.0,
#   'Total': 288.0,
#   'Type': 'Normal'},
#  145: {'Attack': 55.0,
#   'Defense': 50.0,
#   'HP': 55.0,
#   'Name': 'Eevee',
#   'PokedexNumber': 133.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 65.0,
#   'Speed': 55.0,
#   'Total': 325.0,
#   'Type': 'Normal'},
#  146: {'Attack': 65.0,
#   'Defense': 60.0,
#   'HP': 130.0,
#   'Name': 'Vaporeon',
#   'PokedexNumber': 134.0,
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 95.0,
#   'Speed': 65.0,
#   'Total': 525.0,
#   'Type': 'Water'},
#  147: {'Attack': 65.0,
#   'Defense': 60.0,
#   'HP': 65.0,
#   'Name': 'Jolteon',
#   'PokedexNumber': 135.0,
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 95.0,
#   'Speed': 130.0,
#   'Total': 525.0,
#   'Type': 'Electric'},
#  148: {'Attack': 130.0,
#   'Defense': 60.0,
#   'HP': 65.0,
#   'Name': 'Flareon',
#   'PokedexNumber': 136.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 110.0,
#   'Speed': 65.0,
#   'Total': 525.0,
#   'Type': 'Fire'},
#  149: {'Attack': 60.0,
#   'Defense': 70.0,
#   'HP': 65.0,
#   'Name': 'Porygon',
#   'PokedexNumber': 137.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 75.0,
#   'Speed': 40.0,
#   'Total': 395.0,
#   'Type': 'Normal'},
#  150: {'Attack': 40.0,
#   'Defense': 100.0,
#   'HP': 35.0,
#   'Name': 'Omanyte',
#   'PokedexNumber': 138.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 55.0,
#   'Speed': 35.0,
#   'Total': 355.0,
#   'Type': 'RockWater'},
#  151: {'Attack': 60.0,
#   'Defense': 125.0,
#   'HP': 70.0,
#   'Name': 'Omastar',
#   'PokedexNumber': 139.0,
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 70.0,
#   'Speed': 55.0,
#   'Total': 495.0,
#   'Type': 'RockWater'},
#  152: {'Attack': 80.0,
#   'Defense': 90.0,
#   'HP': 30.0,
#   'Name': 'Kabuto',
#   'PokedexNumber': 140.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 45.0,
#   'Speed': 55.0,
#   'Total': 355.0,
#   'Type': 'RockWater'},
#  153: {'Attack': 115.0,
#   'Defense': 105.0,
#   'HP': 60.0,
#   'Name': 'Kabutops',
#   'PokedexNumber': 141.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 70.0,
#   'Speed': 80.0,
#   'Total': 495.0,
#   'Type': 'RockWater'},
#  154: {'Attack': 105.0,
#   'Defense': 65.0,
#   'HP': 80.0,
#   'Name': 'Aerodactyl',
#   'PokedexNumber': 142.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 75.0,
#   'Speed': 130.0,
#   'Total': 515.0,
#   'Type': 'RockFlying'},
#  155: {'Attack': 135.0,
#   'Defense': 85.0,
#   'HP': 80.0,
#   'Name': 'AerodactylMega Aerodactyl',
#   'PokedexNumber': 142.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 95.0,
#   'Speed': 150.0,
#   'Total': 615.0,
#   'Type': 'RockFlying'},
#  156: {'Attack': 110.0,
#   'Defense': 65.0,
#   'HP': 160.0,
#   'Name': 'Snorlax',
#   'PokedexNumber': 143.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 110.0,
#   'Speed': 30.0,
#   'Total': 540.0,
#   'Type': 'Normal'},
#  157: {'Attack': 85.0,
#   'Defense': 100.0,
#   'HP': 90.0,
#   'Name': 'Articuno',
#   'PokedexNumber': 144.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 125.0,
#   'Speed': 85.0,
#   'Total': 580.0,
#   'Type': 'IceFlying'},
#  158: {'Attack': 90.0,
#   'Defense': 85.0,
#   'HP': 90.0,
#   'Name': 'Zapdos',
#   'PokedexNumber': 145.0,
#   'SpecialAttack': 125.0,
#   'SpecialDefense': 90.0,
#   'Speed': 100.0,
#   'Total': 580.0,
#   'Type': 'ElectricFlying'},
#  159: {'Attack': 100.0,
#   'Defense': 90.0,
#   'HP': 90.0,
#   'Name': 'Moltres',
#   'PokedexNumber': 146.0,
#   'SpecialAttack': 125.0,
#   'SpecialDefense': 85.0,
#   'Speed': 90.0,
#   'Total': 580.0,
#   'Type': 'FireFlying'},
#  160: {'Attack': 64.0,
#   'Defense': 45.0,
#   'HP': 41.0,
#   'Name': 'Dratini',
#   'PokedexNumber': 147.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed': 50.0,
#   'Total': 300.0,
#   'Type': 'Dragon'},
#  161: {'Attack': 84.0,
#   'Defense': 65.0,
#   'HP': 61.0,
#   'Name': 'Dragonair',
#   'PokedexNumber': 148.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 70.0,
#   'Speed': 70.0,
#   'Total': 420.0,
#   'Type': 'Dragon'},
#  162: {'Attack': 134.0,
#   'Defense': 95.0,
#   'HP': 91.0,
#   'Name': 'Dragonite',
#   'PokedexNumber': 149.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 100.0,
#   'Speed': 80.0,
#   'Total': 600.0,
#   'Type': 'DragonFlying'},
#  163: {'Attack': 110.0,
#   'Defense': 90.0,
#   'HP': 106.0,
#   'Name': 'Mewtwo',
#   'PokedexNumber': 150.0,
#   'SpecialAttack': 154.0,
#   'SpecialDefense': 90.0,
#   'Speed': 130.0,
#   'Total': 680.0,
#   'Type': 'Psychic'},
#  164: {'Attack': 190.0,
#   'Defense': 100.0,
#   'HP': 106.0,
#   'Name': 'MewtwoMega Mewtwo X',
#   'PokedexNumber': 150.0,
#   'SpecialAttack': 154.0,
#   'SpecialDefense': 100.0,
#   'Speed': 130.0,
#   'Total': 780.0,
#   'Type': 'PsychicFighting'},
#  165: {'Attack': 150.0,
#   'Defense': 70.0,
#   'HP': 106.0,
#   'Name': 'MewtwoMega Mewtwo Y',
#   'PokedexNumber': 150.0,
#   'SpecialAttack': 194.0,
#   'SpecialDefense': 120.0,
#   'Speed': 140.0,
#   'Total': 780.0,
#   'Type': 'Psychic'},
#  166: {'Attack': 100.0,
#   'Defense': 100.0,
#   'HP': 100.0,
#   'Name': 'Mew',
#   'PokedexNumber': 151.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 100.0,
#   'Speed': 100.0,
#   'Total': 600.0,
#   'Type': 'Psychic'},
#  167: {'Attack': 49.0,
#   'Defense': 65.0,
#   'HP': 45.0,
#   'Name': 'Chikorita',
#   'PokedexNumber': 152.0,
#   'SpecialAttack': 49.0,
#   'SpecialDefense': 65.0,
#   'Speed': 45.0,
#   'Total': 318.0,
#   'Type': 'Grass'},
#  168: {'Attack': 62.0,
#   'Defense': 80.0,
#   'HP': 60.0,
#   'Name': 'Bayleef',
#   'PokedexNumber': 153.0,
#   'SpecialAttack': 63.0,
#   'SpecialDefense': 80.0,
#   'Speed': 60.0,
#   'Total': 405.0,
#   'Type': 'Grass'},
#  169: {'Attack': 82.0,
#   'Defense': 100.0,
#   'HP': 80.0,
#   'Name': 'Meganium',
#   'PokedexNumber': 154.0,
#   'SpecialAttack': 83.0,
#   'SpecialDefense': 100.0,
#   'Speed': 80.0,
#   'Total': 525.0,
#   'Type': 'Grass'},
#  170: {'Attack': 52.0,
#   'Defense': 43.0,
#   'HP': 39.0,
#   'Name': 'Cyndaquil',
#   'PokedexNumber': 155.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 50.0,
#   'Speed': 65.0,
#   'Total': 309.0,
#   'Type': 'Fire'},
#  171: {'Attack': 64.0,
#   'Defense': 58.0,
#   'HP': 58.0,
#   'Name': 'Quilava',
#   'PokedexNumber': 156.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 65.0,
#   'Speed': 80.0,
#   'Total': 405.0,
#   'Type': 'Fire'},
#  172: {'Attack': 84.0,
#   'Defense': 78.0,
#   'HP': 78.0,
#   'Name': 'Typhlosion',
#   'PokedexNumber': 157.0,
#   'SpecialAttack': 109.0,
#   'SpecialDefense': 85.0,
#   'Speed': 100.0,
#   'Total': 534.0,
#   'Type': 'Fire'},
#  173: {'Attack': 65.0,
#   'Defense': 64.0,
#   'HP': 50.0,
#   'Name': 'Totodile',
#   'PokedexNumber': 158.0,
#   'SpecialAttack': 44.0,
#   'SpecialDefense': 48.0,
#   'Speed': 43.0,
#   'Total': 314.0,
#   'Type': 'Water'},
#  174: {'Attack': 80.0,
#   'Defense': 80.0,
#   'HP': 65.0,
#   'Name': 'Croconaw',
#   'PokedexNumber': 159.0,
#   'SpecialAttack': 59.0,
#   'SpecialDefense': 63.0,
#   'Speed': 58.0,
#   'Total': 405.0,
#   'Type': 'Water'},
#  175: {'Attack': 105.0,
#   'Defense': 100.0,
#   'HP': 85.0,
#   'Name': 'Feraligatr',
#   'PokedexNumber': 160.0,
#   'SpecialAttack': 79.0,
#   'SpecialDefense': 83.0,
#   'Speed': 78.0,
#   'Total': 530.0,
#   'Type': 'Water'},
#  176: {'Attack': 46.0,
#   'Defense': 34.0,
#   'HP': 35.0,
#   'Name': 'Sentret',
#   'PokedexNumber': 161.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 45.0,
#   'Speed': 20.0,
#   'Total': 215.0,
#   'Type': 'Normal'},
#  177: {'Attack': 76.0,
#   'Defense': 64.0,
#   'HP': 85.0,
#   'Name': 'Furret',
#   'PokedexNumber': 162.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 55.0,
#   'Speed': 90.0,
#   'Total': 415.0,
#   'Type': 'Normal'},
#  178: {'Attack': 30.0,
#   'Defense': 30.0,
#   'HP': 60.0,
#   'Name': 'Hoothoot',
#   'PokedexNumber': 163.0,
#   'SpecialAttack': 36.0,
#   'SpecialDefense': 56.0,
#   'Speed': 50.0,
#   'Total': 262.0,
#   'Type': 'NormalFlying'},
#  179: {'Attack': 50.0,
#   'Defense': 50.0,
#   'HP': 100.0,
#   'Name': 'Noctowl',
#   'PokedexNumber': 164.0,
#   'SpecialAttack': 76.0,
#   'SpecialDefense': 96.0,
#   'Speed': 70.0,
#   'Total': 442.0,
#   'Type': 'NormalFlying'},
#  180: {'Attack': 20.0,
#   'Defense': 30.0,
#   'HP': 40.0,
#   'Name': 'Ledyba',
#   'PokedexNumber': 165.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 80.0,
#   'Speed': 55.0,
#   'Total': 265.0,
#   'Type': 'BugFlying'},
#  181: {'Attack': 35.0,
#   'Defense': 50.0,
#   'HP': 55.0,
#   'Name': 'Ledian',
#   'PokedexNumber': 166.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 110.0,
#   'Speed': 85.0,
#   'Total': 390.0,
#   'Type': 'BugFlying'},
#  182: {'Attack': 60.0,
#   'Defense': 40.0,
#   'HP': 40.0,
#   'Name': 'Spinarak',
#   'PokedexNumber': 167.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 40.0,
#   'Speed': 30.0,
#   'Total': 250.0,
#   'Type': 'BugPoison'},
#  183: {'Attack': 90.0,
#   'Defense': 70.0,
#   'HP': 70.0,
#   'Name': 'Ariados',
#   'PokedexNumber': 168.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed': 40.0,
#   'Total': 390.0,
#   'Type': 'BugPoison'},
#  184: {'Attack': 90.0,
#   'Defense': 80.0,
#   'HP': 85.0,
#   'Name': 'Crobat',
#   'PokedexNumber': 169.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 80.0,
#   'Speed': 130.0,
#   'Total': 535.0,
#   'Type': 'PoisonFlying'},
#  185: {'Attack': 38.0,
#   'Defense': 38.0,
#   'HP': 75.0,
#   'Name': 'Chinchou',
#   'PokedexNumber': 170.0,
#   'SpecialAttack': 56.0,
#   'SpecialDefense': 56.0,
#   'Speed': 67.0,
#   'Total': 330.0,
#   'Type': 'WaterElectric'},
#  186: {'Attack': 58.0,
#   'Defense': 58.0,
#   'HP': 125.0,
#   'Name': 'Lanturn',
#   'PokedexNumber': 171.0,
#   'SpecialAttack': 76.0,
#   'SpecialDefense': 76.0,
#   'Speed': 67.0,
#   'Total': 460.0,
#   'Type': 'WaterElectric'},
#  187: {'Attack': 40.0,
#   'Defense': 15.0,
#   'HP': 20.0,
#   'Name': 'Pichu',
#   'PokedexNumber': 172.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed': 60.0,
#   'Total': 205.0,
#   'Type': 'Electric'},
#  188: {'Attack': 25.0,
#   'Defense': 28.0,
#   'HP': 50.0,
#   'Name': 'Cleffa',
#   'PokedexNumber': 173.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 55.0,
#   'Speed': 15.0,
#   'Total': 218.0,
#   'Type': 'Fairy'},
#  189: {'Attack': 30.0,
#   'Defense': 15.0,
#   'HP': 90.0,
#   'Name': 'Igglybuff',
#   'PokedexNumber': 174.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 20.0,
#   'Speed': 15.0,
#   'Total': 210.0,
#   'Type': 'NormalFairy'},
#  190: {'Attack': 20.0,
#   'Defense': 65.0,
#   'HP': 35.0,
#   'Name': 'Togepi',
#   'PokedexNumber': 175.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 65.0,
#   'Speed': 20.0,
#   'Total': 245.0,
#   'Type': 'Fairy'},
#  191: {'Attack': 40.0,
#   'Defense': 85.0,
#   'HP': 55.0,
#   'Name': 'Togetic',
#   'PokedexNumber': 176.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 105.0,
#   'Speed': 40.0,
#   'Total': 405.0,
#   'Type': 'FairyFlying'},
#  192: {'Attack': 50.0,
#   'Defense': 45.0,
#   'HP': 40.0,
#   'Name': 'Natu',
#   'PokedexNumber': 177.0,
#   'SpecialAttack': 70.0,
#   'SpecialDefense': 45.0,
#   'Speed': 70.0,
#   'Total': 320.0,
#   'Type': 'PsychicFlying'},
#  193: {'Attack': 75.0,
#   'Defense': 70.0,
#   'HP': 65.0,
#   'Name': 'Xatu',
#   'PokedexNumber': 178.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 70.0,
#   'Speed': 95.0,
#   'Total': 470.0,
#   'Type': 'PsychicFlying'},
#  194: {'Attack': 40.0,
#   'Defense': 40.0,
#   'HP': 55.0,
#   'Name': 'Mareep',
#   'PokedexNumber': 179.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 45.0,
#   'Speed': 35.0,
#   'Total': 280.0,
#   'Type': 'Electric'},
#  195: {'Attack': 55.0,
#   'Defense': 55.0,
#   'HP': 70.0,
#   'Name': 'Flaaffy',
#   'PokedexNumber': 180.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 60.0,
#   'Speed': 45.0,
#   'Total': 365.0,
#   'Type': 'Electric'},
#  196: {'Attack': 75.0,
#   'Defense': 85.0,
#   'HP': 90.0,
#   'Name': 'Ampharos',
#   'PokedexNumber': 181.0,
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 90.0,
#   'Speed': 55.0,
#   'Total': 510.0,
#   'Type': 'Electric'},
#  197: {'Attack': 95.0,
#   'Defense': 105.0,
#   'HP': 90.0,
#   'Name': 'AmpharosMega Ampharos',
#   'PokedexNumber': 181.0,
#   'SpecialAttack': 165.0,
#   'SpecialDefense': 110.0,
#   'Speed': 45.0,
#   'Total': 610.0,
#   'Type': 'ElectricDragon'},
#  198: {'Attack': 80.0,
#   'Defense': 95.0,
#   'HP': 75.0,
#   'Name': 'Bellossom',
#   'PokedexNumber': 182.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 100.0,
#   'Speed': 50.0,
#   'Total': 490.0,
#   'Type': 'Grass'},
#  199: {'Attack': 20.0,
#   'Defense': 50.0,
#   'HP': 70.0,
#   'Name': 'Marill',
#   'PokedexNumber': 183.0,
#   'SpecialAttack': 20.0,
#   'SpecialDefense': 50.0,
#   'Speed': 40.0,
#   'Total': 250.0,
#   'Type': 'WaterFairy'},
#  200: {'Attack': 50.0,
#   'Defense': 80.0,
#   'HP': 100.0,
#   'Name': 'Azumarill',
#   'PokedexNumber': 184.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 80.0,
#   'Speed': 50.0,
#   'Total': 420.0,
#   'Type': 'WaterFairy'},
#  201: {'Attack': 100.0,
#   'Defense': 115.0,
#   'HP': 70.0,
#   'Name': 'Sudowoodo',
#   'PokedexNumber': 185.0,
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 65.0,
#   'Speed': 30.0,
#   'Total': 410.0,
#   'Type': 'Rock'},
#  202: {'Attack': 75.0,
#   'Defense': 75.0,
#   'HP': 90.0,
#   'Name': 'Politoed',
#   'PokedexNumber': 186.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 100.0,
#   'Speed': 70.0,
#   'Total': 500.0,
#   'Type': 'Water'},
#  203: {'Attack': 35.0,
#   'Defense': 40.0,
#   'HP': 35.0,
#   'Name': 'Hoppip',
#   'PokedexNumber': 187.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 55.0,
#   'Speed': 50.0,
#   'Total': 250.0,
#   'Type': 'GrassFlying'},
#  204: {'Attack': 45.0,
#   'Defense': 50.0,
#   'HP': 55.0,
#   'Name': 'Skiploom',
#   'PokedexNumber': 188.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 65.0,
#   'Speed': 80.0,
#   'Total': 340.0,
#   'Type': 'GrassFlying'},
#  205: {'Attack': 55.0,
#   'Defense': 70.0,
#   'HP': 75.0,
#   'Name': 'Jumpluff',
#   'PokedexNumber': 189.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 95.0,
#   'Speed': 110.0,
#   'Total': 460.0,
#   'Type': 'GrassFlying'},
#  206: {'Attack': 70.0,
#   'Defense': 55.0,
#   'HP': 55.0,
#   'Name': 'Aipom',
#   'PokedexNumber': 190.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 55.0,
#   'Speed': 85.0,
#   'Total': 360.0,
#   'Type': 'Normal'},
#  207: {'Attack': 30.0,
#   'Defense': 30.0,
#   'HP': 30.0,
#   'Name': 'Sunkern',
#   'PokedexNumber': 191.0,
#   'SpecialAttack': 30.0,
#   'SpecialDefense': 30.0,
#   'Speed': 30.0,
#   'Total': 180.0,
#   'Type': 'Grass'},
#  208: {'Attack': 75.0,
#   'Defense': 55.0,
#   'HP': 75.0,
#   'Name': 'Sunflora',
#   'PokedexNumber': 192.0,
#   'SpecialAttack': 105.0,
#   'SpecialDefense': 85.0,
#   'Speed': 30.0,
#   'Total': 425.0,
#   'Type': 'Grass'},
#  209: {'Attack': 65.0,
#   'Defense': 45.0,
#   'HP': 65.0,
#   'Name': 'Yanma',
#   'PokedexNumber': 193.0,
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 45.0,
#   'Speed': 95.0,
#   'Total': 390.0,
#   'Type': 'BugFlying'},
#  210: {'Attack': 45.0,
#   'Defense': 45.0,
#   'HP': 55.0,
#   'Name': 'Wooper',
#   'PokedexNumber': 194.0,
#   'SpecialAttack': 25.0,
#   'SpecialDefense': 25.0,
#   'Speed': 15.0,
#   'Total': 210.0,
#   'Type': 'WaterGround'},
#  211: {'Attack': 85.0,
#   'Defense': 85.0,
#   'HP': 95.0,
#   'Name': 'Quagsire',
#   'PokedexNumber': 195.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed': 35.0,
#   'Total': 430.0,
#   'Type': 'WaterGround'},
#  212: {'Attack': 65.0,
#   'Defense': 60.0,
#   'HP': 65.0,
#   'Name': 'Espeon',
#   'PokedexNumber': 196.0,
#   'SpecialAttack': 130.0,
#   'SpecialDefense': 95.0,
#   'Speed': 110.0,
#   'Total': 525.0,
#   'Type': 'Psychic'},
#  213: {'Attack': 65.0,
#   'Defense': 110.0,
#   'HP': 95.0,
#   'Name': 'Umbreon',
#   'PokedexNumber': 197.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 130.0,
#   'Speed': 65.0,
#   'Total': 525.0,
#   'Type': 'Dark'},
#  214: {'Attack': 85.0,
#   'Defense': 42.0,
#   'HP': 60.0,
#   'Name': 'Murkrow',
#   'PokedexNumber': 198.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 42.0,
#   'Speed': 91.0,
#   'Total': 405.0,
#   'Type': 'DarkFlying'},
#  215: {'Attack': 75.0,
#   'Defense': 80.0,
#   'HP': 95.0,
#   'Name': 'Slowking',
#   'PokedexNumber': 199.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 110.0,
#   'Speed': 30.0,
#   'Total': 490.0,
#   'Type': 'WaterPsychic'},
#  216: {'Attack': 60.0,
#   'Defense': 60.0,
#   'HP': 60.0,
#   'Name': 'Misdreavus',
#   'PokedexNumber': 200.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 85.0,
#   'Speed': 85.0,
#   'Total': 435.0,
#   'Type': 'Ghost'},
#  217: {'Attack': 72.0,
#   'Defense': 48.0,
#   'HP': 48.0,
#   'Name': 'Unown',
#   'PokedexNumber': 201.0,
#   'SpecialAttack': 72.0,
#   'SpecialDefense': 48.0,
#   'Speed': 48.0,
#   'Total': 336.0,
#   'Type': 'Psychic'},
#  218: {'Attack': 33.0,
#   'Defense': 58.0,
#   'HP': 190.0,
#   'Name': 'Wobbuffet',
#   'PokedexNumber': 202.0,
#   'SpecialAttack': 33.0,
#   'SpecialDefense': 58.0,
#   'Speed': 33.0,
#   'Total': 405.0,
#   'Type': 'Psychic'},
#  219: {'Attack': 80.0,
#   'Defense': 65.0,
#   'HP': 70.0,
#   'Name': 'Girafarig',
#   'PokedexNumber': 203.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 65.0,
#   'Speed': 85.0,
#   'Total': 455.0,
#   'Type': 'NormalPsychic'},
#  220: {'Attack': 65.0,
#   'Defense': 90.0,
#   'HP': 50.0,
#   'Name': 'Pineco',
#   'PokedexNumber': 204.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed': 15.0,
#   'Total': 290.0,
#   'Type': 'Bug'},
#  221: {'Attack': 90.0,
#   'Defense': 140.0,
#   'HP': 75.0,
#   'Name': 'Forretress',
#   'PokedexNumber': 205.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed': 40.0,
#   'Total': 465.0,
#   'Type': 'BugSteel'},
#  222: {'Attack': 70.0,
#   'Defense': 70.0,
#   'HP': 100.0,
#   'Name': 'Dunsparce',
#   'PokedexNumber': 206.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 65.0,
#   'Speed': 45.0,
#   'Total': 415.0,
#   'Type': 'Normal'},
#  223: {'Attack': 75.0,
#   'Defense': 105.0,
#   'HP': 65.0,
#   'Name': 'Gligar',
#   'PokedexNumber': 207.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 65.0,
#   'Speed': 85.0,
#   'Total': 430.0,
#   'Type': 'GroundFlying'},
#  224: {'Attack': 85.0,
#   'Defense': 200.0,
#   'HP': 75.0,
#   'Name': 'Steelix',
#   'PokedexNumber': 208.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 65.0,
#   'Speed': 30.0,
#   'Total': 510.0,
#   'Type': 'SteelGround'},
#  225: {'Attack': 125.0,
#   'Defense': 230.0,
#   'HP': 75.0,
#   'Name': 'SteelixMega Steelix',
#   'PokedexNumber': 208.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 95.0,
#   'Speed': 30.0,
# ...
#   'HP': 72.0,
#   'Name': 'Greninja',
#   'PokedexNumber': 658.0,
#   'SpecialAttack': 103.0,
#   'SpecialDefense': 71.0,
#   'Speed': 122.0,
#   'Total': 530.0,
#   'Type': 'WaterDark'},
#  728: {'Attack': 36.0,
#   'Defense': 38.0,
#   'HP': 38.0,
#   'Name': 'Bunnelby',
#   'PokedexNumber': 659.0,
#   'SpecialAttack': 32.0,
#   'SpecialDefense': 36.0,
#   'Speed': 57.0,
#   'Total': 237.0,
#   'Type': 'Normal'},
#  729: {'Attack': 56.0,
#   'Defense': 77.0,
#   'HP': 85.0,
#   'Name': 'Diggersby',
#   'PokedexNumber': 660.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 77.0,
#   'Speed': 78.0,
#   'Total': 423.0,
#   'Type': 'NormalGround'},
#  730: {'Attack': 50.0,
#   'Defense': 43.0,
#   'HP': 45.0,
#   'Name': 'Fletchling',
#   'PokedexNumber': 661.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 38.0,
#   'Speed': 62.0,
#   'Total': 278.0,
#   'Type': 'NormalFlying'},
#  731: {'Attack': 73.0,
#   'Defense': 55.0,
#   'HP': 62.0,
#   'Name': 'Fletchinder',
#   'PokedexNumber': 662.0,
#   'SpecialAttack': 56.0,
#   'SpecialDefense': 52.0,
#   'Speed': 84.0,
#   'Total': 382.0,
#   'Type': 'FireFlying'},
#  732: {'Attack': 81.0,
#   'Defense': 71.0,
#   'HP': 78.0,
#   'Name': 'Talonflame',
#   'PokedexNumber': 663.0,
#   'SpecialAttack': 74.0,
#   'SpecialDefense': 69.0,
#   'Speed': 126.0,
#   'Total': 499.0,
#   'Type': 'FireFlying'},
#  733: {'Attack': 35.0,
#   'Defense': 40.0,
#   'HP': 38.0,
#   'Name': 'Scatterbug',
#   'PokedexNumber': 664.0,
#   'SpecialAttack': 27.0,
#   'SpecialDefense': 25.0,
#   'Speed': 35.0,
#   'Total': 200.0,
#   'Type': 'Bug'},
#  734: {'Attack': 22.0,
#   'Defense': 60.0,
#   'HP': 45.0,
#   'Name': 'Spewpa',
#   'PokedexNumber': 665.0,
#   'SpecialAttack': 27.0,
#   'SpecialDefense': 30.0,
#   'Speed': 29.0,
#   'Total': 213.0,
#   'Type': 'Bug'},
#  735: {'Attack': 52.0,
#   'Defense': 50.0,
#   'HP': 80.0,
#   'Name': 'Vivillon',
#   'PokedexNumber': 666.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 50.0,
#   'Speed': 89.0,
#   'Total': 411.0,
#   'Type': 'BugFlying'},
#  736: {'Attack': 50.0,
#   'Defense': 58.0,
#   'HP': 62.0,
#   'Name': 'Litleo',
#   'PokedexNumber': 667.0,
#   'SpecialAttack': 73.0,
#   'SpecialDefense': 54.0,
#   'Speed': 72.0,
#   'Total': 369.0,
#   'Type': 'FireNormal'},
#  737: {'Attack': 68.0,
#   'Defense': 72.0,
#   'HP': 86.0,
#   'Name': 'Pyroar',
#   'PokedexNumber': 668.0,
#   'SpecialAttack': 109.0,
#   'SpecialDefense': 66.0,
#   'Speed': 106.0,
#   'Total': 507.0,
#   'Type': 'FireNormal'},
#  738: {'Attack': 38.0,
#   'Defense': 39.0,
#   'HP': 44.0,
#   'Name': 'Flab\xc3\xa9b\xc3\xa9',
#   'PokedexNumber': 669.0,
#   'SpecialAttack': 61.0,
#   'SpecialDefense': 79.0,
#   'Speed': 42.0,
#   'Total': 303.0,
#   'Type': 'Fairy'},
#  739: {'Attack': 45.0,
#   'Defense': 47.0,
#   'HP': 54.0,
#   'Name': 'Floette',
#   'PokedexNumber': 670.0,
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 98.0,
#   'Speed': 52.0,
#   'Total': 371.0,
#   'Type': 'Fairy'},
#  740: {'Attack': 65.0,
#   'Defense': 68.0,
#   'HP': 78.0,
#   'Name': 'Florges',
#   'PokedexNumber': 671.0,
#   'SpecialAttack': 112.0,
#   'SpecialDefense': 154.0,
#   'Speed': 75.0,
#   'Total': 552.0,
#   'Type': 'Fairy'},
#  741: {'Attack': 65.0,
#   'Defense': 48.0,
#   'HP': 66.0,
#   'Name': 'Skiddo',
#   'PokedexNumber': 672.0,
#   'SpecialAttack': 62.0,
#   'SpecialDefense': 57.0,
#   'Speed': 52.0,
#   'Total': 350.0,
#   'Type': 'Grass'},
#  742: {'Attack': 100.0,
#   'Defense': 62.0,
#   'HP': 123.0,
#   'Name': 'Gogoat',
#   'PokedexNumber': 673.0,
#   'SpecialAttack': 97.0,
#   'SpecialDefense': 81.0,
#   'Speed': 68.0,
#   'Total': 531.0,
#   'Type': 'Grass'},
#  743: {'Attack': 82.0,
#   'Defense': 62.0,
#   'HP': 67.0,
#   'Name': 'Pancham',
#   'PokedexNumber': 674.0,
#   'SpecialAttack': 46.0,
#   'SpecialDefense': 48.0,
#   'Speed': 43.0,
#   'Total': 348.0,
#   'Type': 'Fighting'},
#  744: {'Attack': 124.0,
#   'Defense': 78.0,
#   'HP': 95.0,
#   'Name': 'Pangoro',
#   'PokedexNumber': 675.0,
#   'SpecialAttack': 69.0,
#   'SpecialDefense': 71.0,
#   'Speed': 58.0,
#   'Total': 495.0,
#   'Type': 'FightingDark'},
#  745: {'Attack': 80.0,
#   'Defense': 60.0,
#   'HP': 75.0,
#   'Name': 'Furfrou',
#   'PokedexNumber': 676.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 90.0,
#   'Speed': 102.0,
#   'Total': 472.0,
#   'Type': 'Normal'},
#  746: {'Attack': 48.0,
#   'Defense': 54.0,
#   'HP': 62.0,
#   'Name': 'Espurr',
#   'PokedexNumber': 677.0,
#   'SpecialAttack': 63.0,
#   'SpecialDefense': 60.0,
#   'Speed': 68.0,
#   'Total': 355.0,
#   'Type': 'Psychic'},
#  747: {'Attack': 48.0,
#   'Defense': 76.0,
#   'HP': 74.0,
#   'Name': 'MeowsticMale',
#   'PokedexNumber': 678.0,
#   'SpecialAttack': 83.0,
#   'SpecialDefense': 81.0,
#   'Speed': 104.0,
#   'Total': 466.0,
#   'Type': 'Psychic'},
#  748: {'Attack': 48.0,
#   'Defense': 76.0,
#   'HP': 74.0,
#   'Name': 'MeowsticFemale',
#   'PokedexNumber': 678.0,
#   'SpecialAttack': 83.0,
#   'SpecialDefense': 81.0,
#   'Speed': 104.0,
#   'Total': 466.0,
#   'Type': 'Psychic'},
#  749: {'Attack': 80.0,
#   'Defense': 100.0,
#   'HP': 45.0,
#   'Name': 'Honedge',
#   'PokedexNumber': 679.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 37.0,
#   'Speed': 28.0,
#   'Total': 325.0,
#   'Type': 'SteelGhost'},
#  750: {'Attack': 110.0,
#   'Defense': 150.0,
#   'HP': 59.0,
#   'Name': 'Doublade',
#   'PokedexNumber': 680.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 49.0,
#   'Speed': 35.0,
#   'Total': 448.0,
#   'Type': 'SteelGhost'},
#  751: {'Attack': 150.0,
#   'Defense': 50.0,
#   'HP': 60.0,
#   'Name': 'AegislashBlade Forme',
#   'PokedexNumber': 681.0,
#   'SpecialAttack': 150.0,
#   'SpecialDefense': 50.0,
#   'Speed': 60.0,
#   'Total': 520.0,
#   'Type': 'SteelGhost'},
#  752: {'Attack': 50.0,
#   'Defense': 150.0,
#   'HP': 60.0,
#   'Name': 'AegislashShield Forme',
#   'PokedexNumber': 681.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 150.0,
#   'Speed': 60.0,
#   'Total': 520.0,
#   'Type': 'SteelGhost'},
#  753: {'Attack': 52.0,
#   'Defense': 60.0,
#   'HP': 78.0,
#   'Name': 'Spritzee',
#   'PokedexNumber': 682.0,
#   'SpecialAttack': 63.0,
#   'SpecialDefense': 65.0,
#   'Speed': 23.0,
#   'Total': 341.0,
#   'Type': 'Fairy'},
#  754: {'Attack': 72.0,
#   'Defense': 72.0,
#   'HP': 101.0,
#   'Name': 'Aromatisse',
#   'PokedexNumber': 683.0,
#   'SpecialAttack': 99.0,
#   'SpecialDefense': 89.0,
#   'Speed': 29.0,
#   'Total': 462.0,
#   'Type': 'Fairy'},
#  755: {'Attack': 48.0,
#   'Defense': 66.0,
#   'HP': 62.0,
#   'Name': 'Swirlix',
#   'PokedexNumber': 684.0,
#   'SpecialAttack': 59.0,
#   'SpecialDefense': 57.0,
#   'Speed': 49.0,
#   'Total': 341.0,
#   'Type': 'Fairy'},
#  756: {'Attack': 80.0,
#   'Defense': 86.0,
#   'HP': 82.0,
#   'Name': 'Slurpuff',
#   'PokedexNumber': 685.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 75.0,
#   'Speed': 72.0,
#   'Total': 480.0,
#   'Type': 'Fairy'},
#  757: {'Attack': 54.0,
#   'Defense': 53.0,
#   'HP': 53.0,
#   'Name': 'Inkay',
#   'PokedexNumber': 686.0,
#   'SpecialAttack': 37.0,
#   'SpecialDefense': 46.0,
#   'Speed': 45.0,
#   'Total': 288.0,
#   'Type': 'DarkPsychic'},
#  758: {'Attack': 92.0,
#   'Defense': 88.0,
#   'HP': 86.0,
#   'Name': 'Malamar',
#   'PokedexNumber': 687.0,
#   'SpecialAttack': 68.0,
#   'SpecialDefense': 75.0,
#   'Speed': 73.0,
#   'Total': 482.0,
#   'Type': 'DarkPsychic'},
#  759: {'Attack': 52.0,
#   'Defense': 67.0,
#   'HP': 42.0,
#   'Name': 'Binacle',
#   'PokedexNumber': 688.0,
#   'SpecialAttack': 39.0,
#   'SpecialDefense': 56.0,
#   'Speed': 50.0,
#   'Total': 306.0,
#   'Type': 'RockWater'},
#  760: {'Attack': 105.0,
#   'Defense': 115.0,
#   'HP': 72.0,
#   'Name': 'Barbaracle',
#   'PokedexNumber': 689.0,
#   'SpecialAttack': 54.0,
#   'SpecialDefense': 86.0,
#   'Speed': 68.0,
#   'Total': 500.0,
#   'Type': 'RockWater'},
#  761: {'Attack': 60.0,
#   'Defense': 60.0,
#   'HP': 50.0,
#   'Name': 'Skrelp',
#   'PokedexNumber': 690.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 60.0,
#   'Speed': 30.0,
#   'Total': 320.0,
#   'Type': 'PoisonWater'},
#  762: {'Attack': 75.0,
#   'Defense': 90.0,
#   'HP': 65.0,
#   'Name': 'Dragalge',
#   'PokedexNumber': 691.0,
#   'SpecialAttack': 97.0,
#   'SpecialDefense': 123.0,
#   'Speed': 44.0,
#   'Total': 494.0,
#   'Type': 'PoisonDragon'},
#  763: {'Attack': 53.0,
#   'Defense': 62.0,
#   'HP': 50.0,
#   'Name': 'Clauncher',
#   'PokedexNumber': 692.0,
#   'SpecialAttack': 58.0,
#   'SpecialDefense': 63.0,
#   'Speed': 44.0,
#   'Total': 330.0,
#   'Type': 'Water'},
#  764: {'Attack': 73.0,
#   'Defense': 88.0,
#   'HP': 71.0,
#   'Name': 'Clawitzer',
#   'PokedexNumber': 693.0,
#   'SpecialAttack': 120.0,
#   'SpecialDefense': 89.0,
#   'Speed': 59.0,
#   'Total': 500.0,
#   'Type': 'Water'},
#  765: {'Attack': 38.0,
#   'Defense': 33.0,
#   'HP': 44.0,
#   'Name': 'Helioptile',
#   'PokedexNumber': 694.0,
#   'SpecialAttack': 61.0,
#   'SpecialDefense': 43.0,
#   'Speed': 70.0,
#   'Total': 289.0,
#   'Type': 'ElectricNormal'},
#  766: {'Attack': 55.0,
#   'Defense': 52.0,
#   'HP': 62.0,
#   'Name': 'Heliolisk',
#   'PokedexNumber': 695.0,
#   'SpecialAttack': 109.0,
#   'SpecialDefense': 94.0,
#   'Speed': 109.0,
#   'Total': 481.0,
#   'Type': 'ElectricNormal'},
#  767: {'Attack': 89.0,
#   'Defense': 77.0,
#   'HP': 58.0,
#   'Name': 'Tyrunt',
#   'PokedexNumber': 696.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 45.0,
#   'Speed': 48.0,
#   'Total': 362.0,
#   'Type': 'RockDragon'},
#  768: {'Attack': 121.0,
#   'Defense': 119.0,
#   'HP': 82.0,
#   'Name': 'Tyrantrum',
#   'PokedexNumber': 697.0,
#   'SpecialAttack': 69.0,
#   'SpecialDefense': 59.0,
#   'Speed': 71.0,
#   'Total': 521.0,
#   'Type': 'RockDragon'},
#  769: {'Attack': 59.0,
#   'Defense': 50.0,
#   'HP': 77.0,
#   'Name': 'Amaura',
#   'PokedexNumber': 698.0,
#   'SpecialAttack': 67.0,
#   'SpecialDefense': 63.0,
#   'Speed': 46.0,
#   'Total': 362.0,
#   'Type': 'RockIce'},
#  770: {'Attack': 77.0,
#   'Defense': 72.0,
#   'HP': 123.0,
#   'Name': 'Aurorus',
#   'PokedexNumber': 699.0,
#   'SpecialAttack': 99.0,
#   'SpecialDefense': 92.0,
#   'Speed': 58.0,
#   'Total': 521.0,
#   'Type': 'RockIce'},
#  771: {'Attack': 65.0,
#   'Defense': 65.0,
#   'HP': 95.0,
#   'Name': 'Sylveon',
#   'PokedexNumber': 700.0,
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 130.0,
#   'Speed': 60.0,
#   'Total': 525.0,
#   'Type': 'Fairy'},
#  772: {'Attack': 92.0,
#   'Defense': 75.0,
#   'HP': 78.0,
#   'Name': 'Hawlucha',
#   'PokedexNumber': 701.0,
#   'SpecialAttack': 74.0,
#   'SpecialDefense': 63.0,
#   'Speed': 118.0,
#   'Total': 500.0,
#   'Type': 'FightingFlying'},
#  773: {'Attack': 58.0,
#   'Defense': 57.0,
#   'HP': 67.0,
#   'Name': 'Dedenne',
#   'PokedexNumber': 702.0,
#   'SpecialAttack': 81.0,
#   'SpecialDefense': 67.0,
#   'Speed': 101.0,
#   'Total': 431.0,
#   'Type': 'ElectricFairy'},
#  774: {'Attack': 50.0,
#   'Defense': 150.0,
#   'HP': 50.0,
#   'Name': 'Carbink',
#   'PokedexNumber': 703.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 150.0,
#   'Speed': 50.0,
#   'Total': 500.0,
#   'Type': 'RockFairy'},
#  775: {'Attack': 50.0,
#   'Defense': 35.0,
#   'HP': 45.0,
#   'Name': 'Goomy',
#   'PokedexNumber': 704.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 75.0,
#   'Speed': 40.0,
#   'Total': 300.0,
#   'Type': 'Dragon'},
#  776: {'Attack': 75.0,
#   'Defense': 53.0,
#   'HP': 68.0,
#   'Name': 'Sliggoo',
#   'PokedexNumber': 705.0,
#   'SpecialAttack': 83.0,
#   'SpecialDefense': 113.0,
#   'Speed': 60.0,
#   'Total': 452.0,
#   'Type': 'Dragon'},
#  777: {'Attack': 100.0,
#   'Defense': 70.0,
#   'HP': 90.0,
#   'Name': 'Goodra',
#   'PokedexNumber': 706.0,
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 150.0,
#   'Speed': 80.0,
#   'Total': 600.0,
#   'Type': 'Dragon'},
#  778: {'Attack': 80.0,
#   'Defense': 91.0,
#   'HP': 57.0,
#   'Name': 'Klefki',
#   'PokedexNumber': 707.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 87.0,
#   'Speed': 75.0,
#   'Total': 470.0,
#   'Type': 'SteelFairy'},
#  779: {'Attack': 70.0,
#   'Defense': 48.0,
#   'HP': 43.0,
#   'Name': 'Phantump',
#   'PokedexNumber': 708.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 60.0,
#   'Speed': 38.0,
#   'Total': 309.0,
#   'Type': 'GhostGrass'},
#  780: {'Attack': 110.0,
#   'Defense': 76.0,
#   'HP': 85.0,
#   'Name': 'Trevenant',
#   'PokedexNumber': 709.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 82.0,
#   'Speed': 56.0,
#   'Total': 474.0,
#   'Type': 'GhostGrass'},
#  781: {'Attack': 66.0,
#   'Defense': 70.0,
#   'HP': 49.0,
#   'Name': 'PumpkabooAverage Size',
#   'PokedexNumber': 710.0,
#   'SpecialAttack': 44.0,
#   'SpecialDefense': 55.0,
#   'Speed': 51.0,
#   'Total': 335.0,
#   'Type': 'GhostGrass'},
#  782: {'Attack': 66.0,
#   'Defense': 70.0,
#   'HP': 44.0,
#   'Name': 'PumpkabooSmall Size',
#   'PokedexNumber': 710.0,
#   'SpecialAttack': 44.0,
#   'SpecialDefense': 55.0,
#   'Speed': 56.0,
#   'Total': 335.0,
#   'Type': 'GhostGrass'},
#  783: {'Attack': 66.0,
#   'Defense': 70.0,
#   'HP': 54.0,
#   'Name': 'PumpkabooLarge Size',
#   'PokedexNumber': 710.0,
#   'SpecialAttack': 44.0,
#   'SpecialDefense': 55.0,
#   'Speed': 46.0,
#   'Total': 335.0,
#   'Type': 'GhostGrass'},
#  784: {'Attack': 66.0,
#   'Defense': 70.0,
#   'HP': 59.0,
#   'Name': 'PumpkabooSuper Size',
#   'PokedexNumber': 710.0,
#   'SpecialAttack': 44.0,
#   'SpecialDefense': 55.0,
#   'Speed': 41.0,
#   'Total': 335.0,
#   'Type': 'GhostGrass'},
#  785: {'Attack': 90.0,
#   'Defense': 122.0,
#   'HP': 65.0,
#   'Name': 'GourgeistAverage Size',
#   'PokedexNumber': 711.0,
#   'SpecialAttack': 58.0,
#   'SpecialDefense': 75.0,
#   'Speed': 84.0,
#   'Total': 494.0,
#   'Type': 'GhostGrass'},
#  786: {'Attack': 85.0,
#   'Defense': 122.0,
#   'HP': 55.0,
#   'Name': 'GourgeistSmall Size',
#   'PokedexNumber': 711.0,
#   'SpecialAttack': 58.0,
#   'SpecialDefense': 75.0,
#   'Speed': 99.0,
#   'Total': 494.0,
#   'Type': 'GhostGrass'},
#  787: {'Attack': 95.0,
#   'Defense': 122.0,
#   'HP': 75.0,
#   'Name': 'GourgeistLarge Size',
#   'PokedexNumber': 711.0,
#   'SpecialAttack': 58.0,
#   'SpecialDefense': 75.0,
#   'Speed': 69.0,
#   'Total': 494.0,
#   'Type': 'GhostGrass'},
#  788: {'Attack': 100.0,
#   'Defense': 122.0,
#   'HP': 85.0,
#   'Name': 'GourgeistSuper Size',
#   'PokedexNumber': 711.0,
#   'SpecialAttack': 58.0,
#   'SpecialDefense': 75.0,
#   'Speed': 54.0,
#   'Total': 494.0,
#   'Type': 'GhostGrass'},
#  789: {'Attack': 69.0,
#   'Defense': 85.0,
#   'HP': 55.0,
#   'Name': 'Bergmite',
#   'PokedexNumber': 712.0,
#   'SpecialAttack': 32.0,
#   'SpecialDefense': 35.0,
#   'Speed': 28.0,
#   'Total': 304.0,
#   'Type': 'Ice'},
#  790: {'Attack': 117.0,
#   'Defense': 184.0,
#   'HP': 95.0,
#   'Name': 'Avalugg',
#   'PokedexNumber': 713.0,
#   'SpecialAttack': 44.0,
#   'SpecialDefense': 46.0,
#   'Speed': 28.0,
#   'Total': 514.0,
#   'Type': 'Ice'},
#  791: {'Attack': 30.0,
#   'Defense': 35.0,
#   'HP': 40.0,
#   'Name': 'Noibat',
#   'PokedexNumber': 714.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 40.0,
#   'Speed': 55.0,
#   'Total': 245.0,
#   'Type': 'FlyingDragon'},
#  792: {'Attack': 70.0,
#   'Defense': 80.0,
#   'HP': 85.0,
#   'Name': 'Noivern',
#   'PokedexNumber': 715.0,
#   'SpecialAttack': 97.0,
#   'SpecialDefense': 80.0,
#   'Speed': 123.0,
#   'Total': 535.0,
#   'Type': 'FlyingDragon'},
#  793: {'Attack': 131.0,
#   'Defense': 95.0,
#   'HP': 126.0,
#   'Name': 'Xerneas',
#   'PokedexNumber': 716.0,
#   'SpecialAttack': 131.0,
#   'SpecialDefense': 98.0,
#   'Speed': 99.0,
#   'Total': 680.0,
#   'Type': 'Fairy'},
#  794: {'Attack': 131.0,
#   'Defense': 95.0,
#   'HP': 126.0,
#   'Name': 'Yveltal',
#   'PokedexNumber': 717.0,
#   'SpecialAttack': 131.0,
#   'SpecialDefense': 98.0,
#   'Speed': 99.0,
#   'Total': 680.0,
#   'Type': 'DarkFlying'},
#  795: {'Attack': 100.0,
#   'Defense': 121.0,
#   'HP': 108.0,
#   'Name': 'Zygarde50% Forme',
#   'PokedexNumber': 718.0,
#   'SpecialAttack': 81.0,
#   'SpecialDefense': 95.0,
#   'Speed': 95.0,
#   'Total': 600.0,
#   'Type': 'DragonGround'},
#  796: {'Attack': 100.0,
#   'Defense': 150.0,
#   'HP': 50.0,
#   'Name': 'Diancie',
#   'PokedexNumber': 719.0,
#   'SpecialAttack': 100.0,
#   'SpecialDefense': 150.0,
#   'Speed': 50.0,
#   'Total': 600.0,
#   'Type': 'RockFairy'},
#  797: {'Attack': 160.0,
#   'Defense': 110.0,
#   'HP': 50.0,
#   'Name': 'DiancieMega Diancie',
#   'PokedexNumber': 719.0,
#   'SpecialAttack': 160.0,
#   'SpecialDefense': 110.0,
#   'Speed': 110.0,
#   'Total': 700.0,
#   'Type': 'RockFairy'},
#  798: {'Attack': 110.0,
#   'Defense': 60.0,
#   'HP': 80.0,
#   'Name': 'HoopaHoopa Confined',
#   'PokedexNumber': 720.0,
#   'SpecialAttack': 150.0,
#   'SpecialDefense': 130.0,
#   'Speed': 70.0,
#   'Total': 600.0,
#   'Type': 'PsychicGhost'},
#  799: {'Attack': 160.0,
#   'Defense': 60.0,
#   'HP': 80.0,
#   'Name': 'HoopaHoopa Unbound',
#   'PokedexNumber': 720.0,
#   'SpecialAttack': 170.0,
#   'SpecialDefense': 130.0,
#   'Speed': 80.0,
#   'Total': 680.0,
#   'Type': 'PsychicDark'},
#  800: {'Attack': 110.0,
#   'Defense': 120.0,
#   'HP': 80.0,
#   'Name': 'Volcanion',
#   'PokedexNumber': 721.0,
#   'SpecialAttack': 130.0,
#   'SpecialDefense': 90.0,
#   'Speed': 70.0,
#   'Total': 600.0,
#   'Type': 'FireWater'}}

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
def filtered_pokedex(pokedex_data, filter=filter_options):
    filtered_list = []
    for poke_id, poke_values in pokedex_data.items():
        match = True
        
        for key, val in filter_options.items():
            cat_match = False
            
            cat_type= type(val)
            if cat_type is str:
                if pokedex_data[poke_id][key].lower() == val.lower():
                    cat_match = True
                    
            elif cat_type is float or cat_type is int:
                if pokedex[poke_id][key] >= val:
                    cat_match = True
            if cat_match and match:
                match = True
            else:
                match = False
        if match:
            filtered_list.append(poke_values)

    return filtered_list
filter_options = {
    'Attack':   50.0,
    'Defense':  80.0,
    'Type':     'Electric'
}


filtered_pokedex(pokedex, filter=filter_options)
# Out:
# [{'Attack': 75.0,
#   'Defense': 85.0,
#   'HP': 90.0,
#   'Name': 'Ampharos',
#   'PokedexNumber': 181.0,
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 90.0,
#   'Speed': 55.0,
#   'Total': 510.0,
#   'Type': 'Electric'},
#  {'Attack': 75.0,
#   'Defense': 80.0,
#   'HP': 70.0,
#   'Name': 'ManectricMega Manectric',
#   'PokedexNumber': 310.0,
#   'SpecialAttack': 135.0,
#   'SpecialDefense': 80.0,
#   'Speed': 135.0,
#   'Total': 575.0,
#   'Type': 'Electric'},
#  {'Attack': 115.0,
#   'Defense': 80.0,
#   'HP': 85.0,
#   'Name': 'Eelektross',
#   'PokedexNumber': 604.0,
#   'SpecialAttack': 105.0,
#   'SpecialDefense': 80.0,
#   'Speed': 50.0,
#   'Total': 515.0,
#   'Type': 'Electric'}]

# %%
###[key for key, value in z.items() if all(item in value for item in search_items)]
##['z']
